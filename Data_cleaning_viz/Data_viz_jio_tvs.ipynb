# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import os

for root, dirs, files in os.walk("."):
    level = root.replace(os.path.sep, "/").count('/')
    indent = " " * 4 * level
    print(f"{indent}📁 {os.path.basename(root)}/")
    subindent = " " * 4 * (level + 1)
    for f in files:
        print(f"{subindent}📄 {f}")
# Out:
# 📁 ./
#     📄 Data_Filtering_tvs_projectors.ipynb
#     📄 DATA_VISUALIZATION_JIO_PROJECTORS.ipynb
#     📄 Data_viz_jio_tvs.ipynb

# %%
df = pd.read_csv(r'D:\VS Python\venv-selenium\JIOMART\jiomart_tvs_projectors_combined_final.csv', encoding='utf-8')
df
# Out:
#                                    Name of the Product Brand Name  \
# 0    Redmi 81.28 cm (32 inch) Smart Fire TV, Black,...      Redmi
# 1    Foxsky 80 cm (32 inch) HD Ready LED Smart TV, ...     Foxsky
# 2    Samsung wondertainment 80 cm (32 Inch) HD Read...    Samsung
# 3    Samsung 108 cm (43 Inch) 4K Ultra HD Smart TV ...    Samsung
# 4    LG 139.7 cm (55 inch) Ultra HD (4K) LED Smart ...         LG
# ..                                                 ...        ...
# 711  Torexo Sales T10 Full HD 1920*1080P Android Pr...     Torexo
# 712  YOTON Andriod 5G WiFi Projector Home 4K Suppor...      YOTON
# 713  ZuZu, move for more better. 3D Full HD LED Pro...      ZuZu,
# 714  IBS Mini ANDRIOD Projector for Home 4K Support...        IBS
# 715  METRONAUT Mini ANDRIOD Projector for Home 4K S...  METRONAUT
#
#     Product Type  Selling Price (INR)  Original Price (INR)  Size (Inch)  \
# 0     Television              10490.0               24999.0         32.0
# ...

# %%
df['Resolution'].unique()
# Out:
# array(['HD READY', '4K', 'FULL HD', 'Not Mentioned', 'UHD', 'FHD',
#        'HD READY/FULL HD'], dtype=object)

# %%
df_tv = df[df['Product Type'] == 'Television']
df_projector = df[df['Product Type'] == 'Projector']
df_tv.info()
df_projector.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 537 entries, 0 to 536
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   537 non-null    object
#  1   Brand Name            537 non-null    object
#  2   Product Type          537 non-null    object
#  3   Selling Price (INR)   537 non-null    float64
#  4   Original Price (INR)  537 non-null    float64
#  5   Size (Inch)           537 non-null    float64
#  6   Size (cm)             537 non-null    float64
#  7   Resolution            537 non-null    object
#  8   Discount (%)          537 non-null    int64
#  9   Bank Offer            537 non-null    object
#  10  Limited Time Deal     537 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 50.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 179 entries, 537 to 715
# Data columns (total 11 columns):
# ...

# %%
# Standardize resolution values
df['Resolution'] = df['Resolution'].replace({
    'FHD': 'FULL HD',
    'UHD': '4K',
    'HD READY/FULL HD': 'HD READY/FULL HD',
    'FULL HD' : 'FULL HD',
    'UHD' : 'UHD'  # Optional, based on how the product behaves  # or keep as 'Unknown'
})
df['Resolution'].unique()
# Out:
# array(['HD READY', '4K', 'FULL HD', 'Not Mentioned', 'UHD',
#        'HD READY/FULL HD'], dtype=object)

# %%
df['Resolution'].unique()
# Out:
# array(['HD READY', '4K', 'FULL HD', 'Not Mentioned', 'UHD',
#        'HD READY/FULL HD'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   716 non-null    object
#  1   Brand Name            716 non-null    object
#  2   Product Type          716 non-null    object
#  3   Selling Price (INR)   716 non-null    float64
#  4   Original Price (INR)  716 non-null    float64
#  5   Size (Inch)           537 non-null    float64
#  6   Size (cm)             537 non-null    float64
#  7   Resolution            716 non-null    object
#  8   Discount (%)          716 non-null    int64
#  9   Bank Offer            716 non-null    object
#  10  Limited Time Deal     716 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 61.7+ KB

# %%
# Product Type distribution
print("Product Type Distribution:")
df['Product Type'].value_counts()
# Visualizing Product Type distribution
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Product Type', order=df['Product Type'].value_counts().index)
for i,v in enumerate(df['Product Type'].value_counts()):
    plt.text(i, v + 10, str(v), ha='center', va='bottom', fontsize=12)
plt.title('Product Type Distribution')
# Out:
# Product Type Distribution:
# Text(0.5, 1.0, 'Product Type Distribution')

# %%
df_tv = df[df['Product Type'] == 'Television']
df_projector = df[df['Product Type'] == 'Projector']
df_tv.info()
df_projector.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 537 entries, 0 to 536
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   537 non-null    object
#  1   Brand Name            537 non-null    object
#  2   Product Type          537 non-null    object
#  3   Selling Price (INR)   537 non-null    float64
#  4   Original Price (INR)  537 non-null    float64
#  5   Size (Inch)           537 non-null    float64
#  6   Size (cm)             537 non-null    float64
#  7   Resolution            537 non-null    object
#  8   Discount (%)          537 non-null    int64
#  9   Bank Offer            537 non-null    object
#  10  Limited Time Deal     537 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 50.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 179 entries, 537 to 715
# Data columns (total 11 columns):
# ...

# %%
df_tv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 537 entries, 0 to 536
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   537 non-null    object
#  1   Brand Name            537 non-null    object
#  2   Product Type          537 non-null    object
#  3   Selling Price (INR)   537 non-null    float64
#  4   Original Price (INR)  537 non-null    float64
#  5   Size (Inch)           537 non-null    float64
#  6   Size (cm)             537 non-null    float64
#  7   Resolution            537 non-null    object
#  8   Discount (%)          537 non-null    int64
#  9   Bank Offer            537 non-null    object
#  10  Limited Time Deal     537 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 50.3+ KB

# %%
import numpy as np

# Create a mask for "Not Mentioned" resolution
mask = df_tv['Resolution'] == 'Not Mentioned'

# Apply the condition using loc
df_tv.loc[mask & (df_tv['Size (Inch)'] > 43), 'Resolution'] = '4K'
df_tv.loc[mask & (df_tv['Size (Inch)'] <= 43), 'Resolution'] = 'HD READY'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set display and plot style
pd.set_option('display.float_format', lambda x: '%.2f' % x)
sns.set(style='whitegrid')
plt.figure(figsize=(12, 6))

# 1. Summary statistics (numerical)
print("\n📊 Summary Statistics:")
print(df_tv.describe())

# 2. Count of each categorical variable
categorical_cols = ['Brand Name', 'Product Type', 'Resolution', 'Bank Offer', 'Limited Time Deal']
print("\n📋 Categorical Value Counts:")
for col in categorical_cols:
    print(f"\n{col}:\n{df_tv[col].value_counts()}")

# 3. Distribution: Selling Price
plt.figure(figsize=(8, 4))
sns.histplot(df_tv['Selling Price (INR)'], kde=True, bins=30)
plt.title('Selling Price Distribution')
plt.xlabel('Selling Price (INR)')
plt.show()

# # 4. Distribution: Original Price
# plt.figure(figsize=(8, 4))
# sns.histplot(df_tv['Original Price (INR)'], kde=True, bins=30)
# plt.title('Original Price Distribution')
# plt.xlabel('Original Price (INR)')
# plt.show()

# # 5. Discount %
# plt.figure(figsize=(8, 4))
# sns.histplot(df_tv['Discount (%)'], kde=True, bins=20)
# plt.title('Discount % Distribution')
# plt.xlabel('Discount (%)')
# plt.show()

# 6. TV Size (Inch)
plt.figure(figsize=(8, 4))
sns.histplot(df_tv['Size (Inch)'], kde=True, bins=15)
plt.title('TV Size (Inch) Distribution')
plt.xlabel('Size (Inch)')
plt.show()

# # 7. TV Size (cm)
# plt.figure(figsize=(8, 4))
# sns.histplot(df_tv['Size (cm)'], kde=True, bins=15)
# plt.title('TV Size (cm) Distribution')
# plt.xlabel('Size (cm)')
# plt.show()

# 8. Resolution type count
plt.figure(figsize=(6, 4))
sns.countplot(data=df_tv, x='Resolution', order=df_tv['Resolution'].value_counts().index)
plt.title('Resolution Types')
plt.xlabel('Resolution')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# 9. Brand distribution (Top 10)
plt.figure(figsize=(10, 4))
top_brands = df_tv['Brand Name'].value_counts().nlargest(10)
sns.barplot(x=top_brands.index, y=top_brands.values)
plt.title('Top 10 Brands')
plt.ylabel('Number of Products')
plt.xlabel('Brand Name')
plt.xticks(rotation=45)
plt.show()

# # 10. Bank Offer types
# plt.figure(figsize=(8, 4))
# top_offers = df_tv['Bank Offer'].value_counts().nlargest(5)
# sns.barplot(x=top_offers.index, y=top_offers.values)
# plt.title('Top Bank Offers')
# plt.ylabel('Count')
# plt.xlabel('Bank Offer Type')
# plt.xticks(rotation=70)
# plt.show()
# Out:
# 📊 Summary Statistics:
#        Selling Price (INR)  Original Price (INR)  Size (Inch)  Size (cm)  \
# count               537.00                537.00       537.00     537.00
# mean              67756.59             119440.52        50.85     128.40
# std               92815.76             193712.31        14.50      36.88
# min                5499.00              10499.00        24.00      60.00
# 25%               21990.00              35990.00        43.00     108.00
# 50%               35999.00              61900.00        50.00     126.00
# 75%               69490.00             119999.00        55.00     140.00
# max              585891.00            2599990.00       120.00     305.00
#
#        Discount (%)
# count        537.00
# mean          39.88
# std           14.34
# min            0.00
# 25%           32.00
# 50%           41.00
# 75%           49.00
# max           83.00
#
# 📋 Categorical Value Counts:
#
# Brand Name:
# Brand Name
# Samsung      82
# LG           65
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set style
sns.set(style="whitegrid")

# # 1. Selling Price vs. Original Price
# plt.figure(figsize=(8, 5))
# sns.scatterplot(data=df_tv, x='Original Price (INR)', y='Selling Price (INR)', hue='Resolution')
# plt.title('Selling Price vs Original Price')
# plt.xlabel('Original Price (INR)')
# plt.ylabel('Selling Price (INR)')
# plt.legend()
# plt.show()

# # 2. Discount vs. Size (Inch)
# plt.figure(figsize=(8, 5))
# sns.scatterplot(data=df_tv, x='Size (Inch)', y='Discount (%)', hue='Resolution')
# plt.title('Discount vs TV Size (Inch)')
# plt.xlabel('Size (Inch)')
# plt.ylabel('Discount (%)')
# plt.legend()
# plt.show()

# 3. Average Selling Price per Brand
plt.figure(figsize=(10, 5))
avg_price = df_tv.groupby('Brand Name')['Selling Price (INR)'].mean().sort_values(ascending=False).head(10)
sns.barplot(x=avg_price.index, y=avg_price.values)
plt.title('Top 10 Brands by Avg Selling Price')
plt.ylabel('Average Selling Price')
plt.xlabel('Brand Name')
plt.xticks(rotation=45)
plt.show()

# 4. Boxplot: Selling Price by Resolution
plt.figure(figsize=(8, 5))
sns.boxplot(data=df_tv, x='Resolution', y='Selling Price (INR)')
plt.title('Selling Price by Resolution Type')
plt.xlabel('Resolution')
plt.ylabel('Selling Price (INR)')
plt.show()


# # 5. Resolution vs Size
# plt.figure(figsize=(8, 5))
# sns.boxplot(data=df_tv, x='Resolution', y='Size (Inch)')
# plt.title('Size Distribution by Resolution')
# plt.xlabel('Resolution')
# plt.ylabel('Size (Inch)')
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: Normalize resolution values
df_tv['Resolution'] = df_tv['Resolution'].replace({
    'FHD': 'FULL HD',
    'UHD': '4K',
    'HD READY/FULL HD': 'FULL HD',
    'Not Mentioned': 'Not Mentioned'
})

# 1. Crosstab: Brand vs Resolution
brand_res = pd.crosstab(df_tv['Brand Name'], df_tv['Resolution'])

# Show top 10 brands
top_brands = df_tv['Brand Name'].value_counts().head(10).index
brand_res_top = brand_res.loc[top_brands]

print("Crosstab - Brands vs Resolution:")
print(brand_res_top)

# 2. Plot as stacked bar chart
brand_res_top.plot(kind='bar', stacked=True, figsize=(12, 6), colormap='Set2')
plt.title('Brand vs Resolution (Top 10 Brands)')
for i, v in enumerate(brand_res_top.sum(axis=1)):
    plt.text(i, v + 2, str(v), ha='center', va='bottom', fontsize=12)
plt.ylabel('Number of Products')
plt.xlabel('Brand Name')
plt.xticks(rotation=45)
plt.legend(title='Resolution')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\saikiran\AppData\Local\Temp\ipykernel_15356\1856252275.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tv['Resolution'] = df_tv['Resolution'].replace({
# Crosstab - Brands vs Resolution:
# Resolution  4K  FULL HD  HD READY
# Brand Name
# Samsung     71        4         7
# LG          57        2         6
# TCL         42        5         5
# Sony        47        1         3
# Hisense     40        1         4
# BPL         10        2        11
# Xiaomi      13        4         5
# Haier       13        0         5
# Kodak       13        1         2
# NVY          5        1         5

# %%
import matplotlib.pyplot as plt

# Get top brands by product count (optional: top 10 for readability)
top_brands = df_tv['Brand Name'].value_counts().head(10)

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_brands.values, labels=top_brands.index, autopct='%1.1f%%', startangle=140)
plt.title('Market Share of Brands (by Product Count)')
plt.axis('equal')  # Equal aspect ratio ensures pie is a circle
plt.tight_layout()
plt.show()

# %%
top_10_4k = df_tv[df_tv['Resolution'] == '4K'].sort_values(by='Selling Price (INR)').head(10)
top_10_4k[['Name of the Product','Brand Name','Selling Price (INR)','Size (Inch)','Resolution']]
# Out:
#                                    Name of the Product Brand Name  \
# 80   LYF 109.22 cm (43 Inch) UHD Smart TV, LD43UL70...        LYF
# 55   Foxsky 109.22 cm (43 inch) 4K Smart WebOS LED ...     Foxsky
# 118  Kodak 7XPro 108 cm (43 inch) Ultra HD (4K) LED...      Kodak
# 403  Itel 109.22 cm (43 Inches) Ultra HD (4K) LED S...       Itel
# 44   NVY 109 cm (43 Inch) Smart 4K LED TV, NVA43SFR...        NVY
# 384  Kodak 108 cm (43 Inch) 4K Ultra HD Smart QLED ...      Kodak
# 464  TCL 108 cm (43 inches) Metallic Bezel-Less Ser...        TCL
# 366  Redmi 109.22 cm (43 inch) Smart Fire TV 4K, F ...      Redmi
# 363  Toshiba 108 cm (43 inch) 4K Ultra HD Vidaa OS ...    Toshiba
# 114  Kodak 7XPro 126 cm (50 inch) Ultra HD (4K) LED...      Kodak
#
#      Selling Price (INR)  Size (Inch) Resolution
# 80              16990.00        43.00         4K
# 55              16998.00        43.00         4K
# 118             18997.00        43.00         4K
# ...

# %% [markdown]
# These are the most affordable 4K TVs available on the JioMart website, offering great features at budget-friendly prices.

# %%
top_10_fhd = df_tv[df_tv['Resolution'] == 'FULL HD'].sort_values(by='Selling Price (INR)').head(10)
top_10_fhd[['Name of the Product','Brand Name','Selling Price (INR)','Size (Inch)','Resolution']]
# Out:
#                                    Name of the Product Brand Name  \
# 365  Foxsky 101 cm (40 inch) Full HD Smart LED TV 4...     Foxsky
# 19   TCL 81.28 cm (32 inch) Full HD Android TV, 32S...        TCL
# 522  Bush 40 inch (100 cm) FHD Smart LED TV, Black,...       Bush
# 71   SKYLIVE 101.6 cm (40 inches) Bezel-Less Full H...    SKYLIVE
# 511         TCL 32 Full HD Smart Android TV, 32S5403AF        TCL
# 5    Foxsky 109 cm (43 Inch) Full HD Smart LED TV, ...     Foxsky
# 369  Foxsky 109 cm (43 inch) Full HD Smart LED TV 4...     Foxsky
# 38   NVY 109 cm (43 Inch) FHD Smart Frameless LED T...        NVY
# 360  SKYLIVE 101.6 cm (40 inches) Bezel-Less Full H...    SKYLIVE
# 265  Kodak 108 cm (43 inch) Full HD TV, 7XPRO Serie...      Kodak
#
#      Selling Price (INR)  Size (Inch) Resolution
# 365             10990.00        40.00    FULL HD
# 19              11990.00        32.00    FULL HD
# 522             11999.00        40.00    FULL HD
# ...

# %% [markdown]
# These are the most affordable Full HD TVs available on the JioMart website, offering great features at budget-friendly prices.

# %%
top_10_fhdready = df_tv[df_tv['Resolution'] == 'HD READY'].sort_values(by='Selling Price (INR)').head(10)
top_10_fhdready[['Name of the Product','Brand Name','Selling Price (INR)','Size (Inch)','Resolution']]
# Out:
#                                    Name of the Product Brand Name  \
# 278   Foxsky 60.96 cm (24 Inch) HD Ready LED TV, 24FSN     Foxsky
# 533  Bush 24 inch (60 cm) HD Normal LED TV, Black, ...       Bush
# 328  Karbonn 60 cm (24 inch) HD Ready LED TV, Mille...    Karbonn
# 1    Foxsky 80 cm (32 inch) HD Ready LED Smart TV, ...     Foxsky
# 345  Sansui Prime Series 60 cm (24 inch) HD Ready L...     Sansui
# 266  LYF 81.28 cm (32 Inch) HD Smart TV, LD32HL2000...        LYF
# 284    Reconnect 80 cm (32 Inch) HD TV, 32H3220, Black  Reconnect
# 98   Karbonn 80 cm (32 inch) HD Ready LED TV, Mille...    Karbonn
# 281  Karbonn 80 cm (32 inch) HD Ready LED TV, Mille...    Karbonn
# 362   Kodak 80 cm (32 inch) HD Ready LED TV, 32HDX900s      Kodak
#
#      Selling Price (INR)  Size (Inch) Resolution
# 278              5499.00        24.00   HD READY
# 533              6499.00        24.00   HD READY
# 328              6999.00        24.00   HD READY
# ...

# %% [markdown]
# These are the most affordable HD Ready TVs available on the JioMart website, offering great features at budget-friendly prices.

# %%
# Top affordable products where according to size of the display
df_tv[df_tv['Size (Inch)'] == 32.00].sort_values(by = 'Selling Price (INR)').head(10)[['Name of the Product','Brand Name','Selling Price (INR)','Size (Inch)','Resolution']]
# Out:
#                                    Name of the Product Brand Name  \
# 1    Foxsky 80 cm (32 inch) HD Ready LED Smart TV, ...     Foxsky
# 266  LYF 81.28 cm (32 Inch) HD Smart TV, LD32HL2000...        LYF
# 284    Reconnect 80 cm (32 Inch) HD TV, 32H3220, Black  Reconnect
# 98   Karbonn 80 cm (32 inch) HD Ready LED TV, Mille...    Karbonn
# 281  Karbonn 80 cm (32 inch) HD Ready LED TV, Mille...    Karbonn
# 32   NVY 80 cm (32 inch) HD Ready Smart Frameless L...        NVY
# 532  Bush 32 inch (80 cm) HD Smart LED TV, Black, J...       Bush
# 362   Kodak 80 cm (32 inch) HD Ready LED TV, 32HDX900s      Kodak
# 83   SKYLIVE 80 cm (32 inches) Bezel-Less Smart And...    SKYLIVE
# 397  Itel 80 cm (32 inch) HD Ready Smart LED TV, L3265       Itel
#
#      Selling Price (INR)  Size (Inch) Resolution
# 1                6999.00        32.00   HD READY
# 266              7989.00        32.00   HD READY
# 284              7989.00        32.00   HD READY
# ...

# %% [markdown]
# These are the most affordable 32-inch televisions available on the JioMart website.

# %%
df_tv[df_tv['Size (Inch)'] == 43.00].sort_values(by = 'Selling Price (INR)').head(10)[['Name of the Product','Brand Name','Selling Price (INR)','Size (Inch)','Resolution']]
# Out:
#                                    Name of the Product Brand Name  \
# 5    Foxsky 109 cm (43 Inch) Full HD Smart LED TV, ...     Foxsky
# 369  Foxsky 109 cm (43 inch) Full HD Smart LED TV 4...     Foxsky
# 38   NVY 109 cm (43 Inch) FHD Smart Frameless LED T...        NVY
# 7    NVY 109 cm (43 inch) QLED Smart TV, NVQ43SFR1,...        NVY
# 265  Kodak 108 cm (43 inch) Full HD TV, 7XPRO Serie...      Kodak
# 523  Bush 43 inch (109 cm) FHD Smart LED TV, Black,...       Bush
# 356  SKYLIVE 109.22 cm (43 inches) Bezel-Less Full ...    SKYLIVE
# 396  Itel 108 cm (43 inch) Full HD Smart LED TV, L4365       Itel
# 59   Reconnect 109 cm (43 inch) FHD Smart Neo TV 43...  Reconnect
# 80   LYF 109.22 cm (43 Inch) UHD Smart TV, LD43UL70...        LYF
#
#      Selling Price (INR)  Size (Inch) Resolution
# 5               13499.00        43.00    FULL HD
# 369             13990.00        43.00    FULL HD
# 38              13999.00        43.00    FULL HD
# ...

# %% [markdown]
# These are the most affordable 43-inch televisions available on the JioMart website.

# %%
df_tv[df_tv['Size (Inch)'] == 50.00].sort_values(by = 'Selling Price (INR)').head(10)[['Name of the Product','Brand Name','Selling Price (INR)','Size (Inch)','Resolution']]
# Out:
#                                    Name of the Product Brand Name  \
# 114  Kodak 7XPro 126 cm (50 inch) Ultra HD (4K) LED...      Kodak
# 534  Bush 50 inch (127 cm) 4K UHD Smart LED TV, Bla...       Bush
# 101  Kodak 126 cm (50 Inch) Matrix Series 4K Ultra ...      Kodak
# 499  Kodak 126 cm (50 inch) Ultra HD (4K) LED Smart...      Kodak
# 463  TCL 126 cm (50 inches) Metallic Bezel-Less Ser...        TCL
# 211  IFFALCON by TCL 126 cm (50 inches) 4K Ultra HD...   IFFALCON
# 387  Hisense 50A6K 126 cm (50 inches) 4K UHD Smart ...    Hisense
# 320  Kodak 126 cm (50 inch) Ultra HD (4K) Smart LED...      Kodak
# 479  Acer 127 cm (50 inches) Advanced I Series 4K U...       Acer
# 495  TOSHIBA 126 cm (50 inch) 4K Ultra HD Smart LED...    TOSHIBA
#
#      Selling Price (INR)  Size (Inch) Resolution
# 114             22998.00        50.00         4K
# 534             25999.00        50.00         4K
# 101             26499.00        50.00         4K
# ...

# %% [markdown]
# These are the most affordable 50-inch televisions available on the JioMart website.

# %%
df_tv[df_tv['Size (Inch)'] == 55.00].sort_values(by = 'Selling Price (INR)').head(10)[['Name of the Product','Brand Name','Selling Price (INR)','Size (Inch)','Resolution']]
# Out:
#                                    Name of the Product Brand Name  \
# 108  Kodak 7XPro 139 cm (55 inch) Ultra HD (4K) LED...      Kodak
# 29   Foxsky 139.7 cm (55 inch) 4K Ultra HD LED Smar...     Foxsky
# 149  NVY 140 cm (55 inches) 4K Ultra HD Smart Googl...        NVY
# 90   Aiwa 139 cm (55 Inch) Ultra HD (4K) Smart TV, ...       Aiwa
# 69   Realme 139 cm (55 inch) Ultra HD (4K) LED Smar...     Realme
# 424  TCL 139 cm (55 inches) Metallic Bezel-Less Ser...        TCL
# 113  iFFALCON 139 cm (55 inches) 4K Ultra HD Smart ...   iFFALCON
# 37   Acer 139 cm (55 inches) Advanced I Series 4K U...       Acer
# 111  Hisense 139 cm (55 inches) 4K Ultra HD Smart G...    Hisense
# 121  Acer L Series 139 cm (55 inches) 4K Ultra HD S...       Acer
#
#      Selling Price (INR)  Size (Inch) Resolution
# 108             25998.00        55.00         4K
# 29              26999.00        55.00         4K
# 149             27990.00        55.00         4K
# ...

# %% [markdown]
# These are the most affordable 55-inch televisions available on the JioMart website.

# %%
df_tv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 537 entries, 0 to 536
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   537 non-null    object
#  1   Brand Name            537 non-null    object
#  2   Product Type          537 non-null    object
#  3   Selling Price (INR)   537 non-null    float64
#  4   Original Price (INR)  537 non-null    float64
#  5   Size (Inch)           537 non-null    float64
#  6   Size (cm)             537 non-null    float64
#  7   Resolution            537 non-null    object
#  8   Discount (%)          537 non-null    int64
#  9   Bank Offer            537 non-null    object
#  10  Limited Time Deal     537 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 50.3+ KB

# %%
df_tv[df_tv['Size (Inch)'] > 55.00].sort_values(by = 'Selling Price (INR)').head(10)[['Name of the Product','Brand Name','Selling Price (INR)','Size (Inch)','Resolution']]
# Out:
#                                    Name of the Product Brand Name  \
# 344  Philips 146 cm (58 inch) Ultra HD (4K) LED Sma...    Philips
# 258  TCL 147.32 cm (58 Inch) Ultra HD (4K) Smart TV...        TCL
# 267  TCL 165.1 cm (65 inch) Ultra HD (4K) Smart TV,...        TCL
# 84   Sansui 165 cm (65 inches) 4K Ultra HD Smart An...     Sansui
# 466  TCL 164 cm (65 inches) Metallic Bezel-Less Ser...        TCL
# 203  iFFALCON 164 cm (65 inches) 4K Ultra HD Smart ...   iFFALCON
# 231  Hisense 164 cm (65 inches) 4K UHD Smart Google...    Hisense
# 218  BPL 165 cm (65 inch) Ultra HD (4K) Google Smar...        BPL
# 342  Kodak 164 cm (65 inch) Ultra HD (4K) Premium A...      Kodak
# 468  TCL 165 cm (65 inches) 4K Ultra HD Smart QLED ...        TCL
#
#      Selling Price (INR)  Size (Inch) Resolution
# 344             29990.00        58.00         4K
# 258             39990.00        58.00         4K
# 267             43988.00        65.00         4K
# ...

# %% [markdown]
# These are the most affordable more than 55-inch televisions available on the JioMart website.

# %%
df_tv[df_tv['Size (Inch)'] > 55.00].sort_values(by = 'Selling Price (INR)', ascending= False).head(10)[['Name of the Product','Brand Name','Selling Price (INR)','Size (Inch)','Resolution']]
# Out:
#                                    Name of the Product Brand Name  \
# 247  Sony Bravia 210 cm (83 inches) XR Series 4K Ul...       Sony
# 133  Sony BRAVIA 9 Series 215 cm (85 inches) 4K Ult...       Sony
# 440  LG 195.5 cm (77 inch) OLED Evo AI G5 4K 165Hz ...         LG
# 481      LG 218 cm (86 inch) 4K QNED Smart TV 86QNED80         LG
# 496  Samsung 215.9 cm (85 inch) QLED Smart LED TV 8...    Samsung
# 381  Samsung 214 cm (85 Inch) 4K Neo-QLED Smart TV ...    Samsung
# 378  LG 195.58 cm (77 inch) 4K Ultra HD OLED TV, Bl...         LG
# 485  Hisense 305 cm (120 Inch) Ultra HD (4K) Smart ...    Hisense
# 526          Samsung 85 Neo QLED Smart LED TV, 85QN90C    Samsung
# 236  Sony X95L 215 cm (85 inches) TV -XR-85X95L: BR...       Sony
#
#      Selling Price (INR)  Size (Inch) Resolution
# 247            585891.00        83.00         4K
# 133            557991.00        85.00         4K
# 440            556490.00        77.00         4K
# ...

# %% [markdown]
# These are the most expensive more than 55-inch televisions available on the JioMart website.

# %%
df_tv[df_tv['Size (Inch)'] == 55.00].sort_values(by = 'Selling Price (INR)', ascending= False).head(10)[['Name of the Product','Brand Name','Selling Price (INR)','Size (Inch)','Resolution']]
# Out:
#                                    Name of the Product Brand Name  \
# 132  Sony BRAVIA 8 Series 139 cm (55 inches) 4K Ult...       Sony
# 178  Samsung 138 cm (55 Inch) 4K OLED Smart TV (QA5...    Samsung
# 492  Haier 140cm (55 inch) 4K OLED Smart Google TV,...      Haier
# 148  Sony BRAVIA 7 Series 139 cm (55 inches) 4K Ult...       Sony
# 95   Samsung 138 cm (55 Inch) 4K OLED Smart TV (QA5...    Samsung
# 276  LG 139 cm (55 Inch) Ultra HD (4K) OLED Smart T...         LG
# 508          Samsung 55 Neo QLED Smart LED TV, 55QN95C    Samsung
# 181  Samsung 138 cm (55 Inch) 4K Neo-QLED Smart TV ...    Samsung
# 26   LG 139.7 cm (55 inches) 4K Smart OLED TV, OLED...         LG
# 105  Samsung 138 cm (55 Inch) 4K Neo-QLED Smart TV ...    Samsung
#
#      Selling Price (INR)  Size (Inch) Resolution
# 132            197990.00        55.00         4K
# 178            182489.00        55.00         4K
# 492            161989.00        55.00         4K
# ...

# %% [markdown]
# These are the most expensive 55-inch televisions available on the JioMart website.

# %%
df_tv[df_tv['Resolution'] == '4K'].sort_values(by = 'Selling Price (INR)').head(10)[['Name of the Product','Brand Name','Selling Price (INR)','Size (Inch)','Resolution']]
# Out:
#                                    Name of the Product Brand Name  \
# 80   LYF 109.22 cm (43 Inch) UHD Smart TV, LD43UL70...        LYF
# 55   Foxsky 109.22 cm (43 inch) 4K Smart WebOS LED ...     Foxsky
# 118  Kodak 7XPro 108 cm (43 inch) Ultra HD (4K) LED...      Kodak
# 403  Itel 109.22 cm (43 Inches) Ultra HD (4K) LED S...       Itel
# 44   NVY 109 cm (43 Inch) Smart 4K LED TV, NVA43SFR...        NVY
# 384  Kodak 108 cm (43 Inch) 4K Ultra HD Smart QLED ...      Kodak
# 464  TCL 108 cm (43 inches) Metallic Bezel-Less Ser...        TCL
# 366  Redmi 109.22 cm (43 inch) Smart Fire TV 4K, F ...      Redmi
# 363  Toshiba 108 cm (43 inch) 4K Ultra HD Vidaa OS ...    Toshiba
# 114  Kodak 7XPro 126 cm (50 inch) Ultra HD (4K) LED...      Kodak
#
#      Selling Price (INR)  Size (Inch) Resolution
# 80              16990.00        43.00         4K
# 55              16998.00        43.00         4K
# 118             18997.00        43.00         4K
# ...

# %%
df_tv.groupby('Brand Name')['Selling Price (INR)'].agg(
    Total_Sales='sum',
    Product_Count='count'
).sort_values(by='Total_Sales', ascending=False).head(10)
# Out:
#             Total_Sales  Product_Count
# Brand Name
# Samsung      8979628.00             82
# LG           7894720.00             65
# Sony         6844066.00             51
# TCL          3280972.00             52
# Hisense      2721398.00             45
# Haier        1002215.00             18
# BPL           681432.00             23
# Xiaomi        607950.00             22
# Kodak         391974.00             16
# iFFALCON      286982.00              7

# %%
df_tv.groupby('Brand Name')['Selling Price (INR)'].agg(
    Average_Sales='mean',
    Product_count='count'
).query('Product_count >= 15').sort_values(by='Average_Sales', ascending=False)
# Out:
#             Average_Sales  Product_count
# Brand Name
# Sony            134197.37             51
# LG              121457.23             65
# Samsung         109507.66             82
# TCL              63095.62             52
# Hisense          60475.51             45
# Haier            55678.61             18
# BPL              29627.48             23
# Xiaomi           27634.09             22
# Kodak            24498.38             16

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Apply seaborn theme first
sns.set_theme(style='darkgrid')  # Apply before plotting

# Grouped summary
brand_summary = df_tv.groupby('Brand Name')['Selling Price (INR)'].agg(
    Average_Sales='mean',
    Product_Count='count'
).query('Product_Count >= 15').sort_values(by='Average_Sales', ascending=False)

# Extract values
brands = brand_summary.index.tolist()
sales = brand_summary['Average_Sales'].tolist()
counts = brand_summary['Product_Count'].tolist()

# Plotting
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for Average Sales
bars = ax1.bar(brands, sales, color='skyblue')
ax1.set_ylabel('Average Price (INR)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Annotate bars (above bar)
for bar, value in zip(bars, sales):
    ax1.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 8000, f'{int(value):,}', 
             ha='center', va='bottom', fontsize=9, color='blue')

# Line plot for Product Count
ax2 = ax1.twinx()
ax2.plot(brands, counts, color='orange', marker='o', linewidth=2)
ax2.set_ylabel('Product Count', color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

# Annotate product count points (below marker)
for i, count in enumerate(counts):
    ax2.text(i, count + 1, str(count), ha='center', va='bottom', fontsize=9, color='red')

# Final touches
plt.title('Average Price and Product Count by Brand')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 💡 Average Price and Product Count by Brand
#
# This dual-axis visualization helps you understand:
#
# - **Average Price (INR)** – represented using **light blue bars**
# - **Product Count** – shown using an **orange line with circular markers**
#
# #### Key Takeaways:
# - 💰 **Sony** has the highest average price (~₹134,197), followed by **LG** and **Samsung**.
# - 📦 **Samsung** leads in product variety with **82 products**, even though its average price is slightly lower than Sony and LG.
# - ⚖️ **TCL**, **Hisense**, and **Haier** offer moderately priced TVs with decent variety.
# - 📉 **BPL**, **Xiaomi**, and **Kodak** target the budget segment with both lower prices and fewer product options.
#
# Each **bar** is labeled with the average price (formatted), and each **point** is annotated with the product count.
#
# > 📊 This chart gives a clearer perspective on how premium pricing and product diversity vary across brands.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Seaborn theme
sns.set_theme(style='whitegrid')

# Group data
brand_summary = df_tv.groupby('Brand Name')['Selling Price (INR)'].agg(
    Total_Sales='sum',
    Product_Count='count'
).sort_values(by='Total_Sales', ascending=False).head(10)

# Extract values
brands = brand_summary.index.tolist()
sales = brand_summary['Total_Sales'].tolist()
counts = brand_summary['Product_Count'].tolist()

# Plot
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot (total sales)
bars = ax1.bar(brands, sales, color='darkblue')
ax1.set_ylabel('Total Sales (INR)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Annotate bars (below top)
for bar, value in zip(bars, sales):
    ax1.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 100000, f'{int(value):,}', 
             ha='center', va='bottom', fontsize=9, color='blue')


# Line plot (product count)
ax2 = ax1.twinx()
ax2.plot(brands, counts, color='orange', marker='o', linewidth=2)
ax2.set_ylabel('Product Count', color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

# Annotate points (slightly below)
for i, count in enumerate(counts):
    ax2.text(i, count - 1, str(count), ha='center', va='top', fontsize=9, color='orange')

# Final touches
plt.title('Total Sales and Product Count by Brand')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
sns.set_theme(style='darkgrid')  # Options: darkgrid, whitegrid, dark, white, ticks

# %% [markdown]
# ### 📊 Total Sales and Product Count by Brand
#
# This visualization combines a **bar chart** and a **line chart** to show how the top 10 TV brands perform in terms of:
#
# - **Total Sales (INR)** – shown using **blue bars**.
# - **Product Count** – shown using an **orange line** with markers.
#
# #### Key Insights:
# - 📈 **Samsung** dominates with the highest total sales (~₹8.98 million) and the most diverse product range (82 models).
# - 🏷️ **LG** and **Sony** follow closely, offering a large number of products with high cumulative sales.
# - ⚖️ Brands like **TCL** and **Hisense** maintain a balance between product count and total revenue.
# - 📉 **Haier**, **BPL**, **Xiaomi**, **Kodak**, and **iFFALCON** show comparatively lower sales and fewer product listings.
#
# Both values (sales and counts) are annotated directly on the chart for better readability.
#
# > 💡 This dual-axis chart helps visualize how product diversity correlates with total revenue for each brand.

# %%
# Grouping TV data by size and aggregating total sales, product count, and average price
size_summary = df_tv.groupby('Size (Inch)')['Selling Price (INR)'].agg(
    Total_Sales='sum',
    Product_Count='count',
    Average_Price_Per_Size='mean'
).query('Product_Count >= 10')

# Display the summarized DataFrame
size_summary.sort_values(by = 'Total_Sales', ascending= False)
# Out:
#              Total_Sales  Product_Count  Average_Price_Per_Size
# Size (Inch)
# 65.00         8217446.00             75               109565.95
# 55.00         6236100.00            106                58831.13
# 75.00         4979725.00             32               155616.41
# 43.00         3824840.00            129                29649.92
# 85.00         3801504.00             11               345591.27
# 50.00         2162107.00             52                41578.98
# 32.00         1221540.00             94                12995.11
# 40.00          215828.00             13                16602.15

# %% [markdown]
# ### 📊 Sales Analysis by TV Size
#
# The table below summarizes **TV sales performance by screen size**, showing:
#
# - **Total Sales** in INR
# - **Number of Products** available in each size category
# - **Average Price** per size
#
# Only sizes with more than **10 products** are included.
#
# | Size (Inch) | Total Sales (INR) | Product Count | Avg. Price per Size (INR) |
# |-------------|-------------------|----------------|----------------------------|
# | 65          | ₹8,217,446        | 75             | ₹1,09,566                  |
# | 55          | ₹6,236,100        | 106            | ₹58,831                    |
# | 75          | ₹4,979,725        | 32             | ₹1,55,616                  |
# | 43          | ₹3,824,840        | 129            | ₹29,650                    |
# | 85          | ₹3,801,504        | 11             | ₹3,45,591                  |
# | 50          | ₹2,162,107        | 52             | ₹41,579                    |
# | 32          | ₹1,221,540        | 94             | ₹12,995                    |
# | 40          | ₹215,828          | 13             | ₹16,602                    |
#
# 📝 **Insights:**
# - **65" and 55" TVs** dominate in total sales, with high volume and strong average prices.
# - **85" TVs** have the highest average price, but low product count.
# - **32" and 43" TVs** are budget-friendly with high availability.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter sizes with more than 10 products
size_summary = df_tv.groupby('Size (Inch)')['Selling Price (INR)'].agg(
    Total_Sales='sum',
    Product_Count='count',
    Average_Price_Per_Size='mean'
).query('Product_Count > 10').sort_values(by='Total_Sales', ascending=False)

# Extract data
sizes = size_summary.index.astype(str)
total_sales = size_summary['Total_Sales']
product_counts = size_summary['Product_Count']

# Plot settings
sns.set_theme(style='whitegrid')
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar chart: Total Sales
bars = ax1.bar(sizes, total_sales, color='skyblue')
ax1.set_ylabel('Total Sales (INR)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Annotate total sales on top
for bar, value in zip(bars, total_sales):
    ax1.text(bar.get_x() + bar.get_width()/2, value + 100000, f'{int(value):,}', 
             ha='center', va='bottom', fontsize=9, color='blue')

# Line chart: Product Count
ax2 = ax1.twinx()
ax2.plot(sizes, product_counts, color='orange', marker='o', linewidth=2)
ax2.set_ylabel('Product Count', color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

# Annotate product counts
for i, count in enumerate(product_counts):
    ax2.text(i, count + 1, str(count), ha='center', va='bottom', fontsize=9, color='red')

# Final touches
plt.title('Total Sales and Product Count by TV Size')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Prepare data (filtered)
size_summary = df_tv.groupby('Size (Inch)')['Selling Price (INR)'].agg(
    Total_Sales='sum',
    Product_Count='count',
    Average_Price_Per_Size='mean'
).query('Product_Count > 10').sort_values(by='Total_Sales', ascending=False)

# Extract data
sizes = size_summary.index.astype(str)
total_sales = size_summary['Total_Sales']
product_counts = size_summary['Product_Count']
avg_prices = size_summary['Average_Price_Per_Size']

# Set seaborn style without grid
sns.set_style("white")

# Create plot
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot: Total Sales
bars = ax1.bar(sizes, total_sales, color='#1f77b4', label='Total Sales (INR)')
ax1.set_ylabel('Total Sales (INR)', color='#1f77b4')
ax1.tick_params(axis='y', labelcolor='#1f77b4')
ax1.set_axisbelow(True)

# Add value labels on bars
for bar, val in zip(bars, total_sales):
    ax1.text(bar.get_x() + bar.get_width() / 2, val + 100000, f'{int(val):,}',
             ha='center', va='bottom', fontsize=9, color='#1f77b4')

# Line plot: Product Count
ax2 = ax1.twinx()
ax2.plot(sizes, product_counts, color='#ff7f0e', marker='o', linewidth=2, label='Product Count')
ax2.set_ylabel('Product Count', color='#ff7f0e')
ax2.tick_params(axis='y', labelcolor='#ff7f0e')
for i, count in enumerate(product_counts):
    ax2.text(i, count + 5, str(count), ha='center', va='bottom', fontsize=9, color='#ff7f0e')

# Line plot: Average Price (rounded)
ax3 = ax1.twinx()
ax3.spines["right"].set_position(("axes", 1.1))
ax3.plot(sizes, avg_prices, color='#2ca02c', marker='s', linestyle='--', linewidth=2, label='Avg Price')
ax3.set_ylabel('Average Price (INR)', color='#2ca02c')
ax3.tick_params(axis='y', labelcolor="#0a130a")
for i, price in enumerate(avg_prices):
    ax3.text(i, price + 10000, f'{int(price):,}', ha='center', va='bottom', fontsize=9, color="#86221beb")

# Title and layout
plt.title('TV Size vs Total Sales, Product Count, and Avg Price')
fig.tight_layout()
fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.92), ncol=3)

# Turn off grid
ax1.grid(False)
ax2.grid(False)
ax3.grid(False)

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 📊 TV Size vs Total Sales, Product Count, and Average Price
#
# This visualization shows the relationship between **TV screen sizes (in inches)** and the following aggregated metrics:
#
# - **🔷 Total Sales (INR)** – represented by the blue bars.
# - **🟠 Product Count** – shown with the orange line and markers.
# - **🟢 Average Price per Size** – illustrated by the green dashed line (rounded to nearest INR).
#
# #### Key Insights:
# - **65" TVs** generate the **highest total sales** overall, despite not having the highest product count.
# - **43" and 32" TVs** have **high product counts**, indicating popularity, but relatively **lower average prices**.
# - **85" TVs** have the **highest average price**, but fewer units sold.
# - Sizes with a **Product Count > 10** are included to ensure statistical relevance.
#
# This multi-axis visualization helps in understanding both market trends and consumer preferences by combining volume, variety, and pricing.
#
# ---

# %%
Resolution_summary = df_tv.groupby('Resolution')['Selling Price (INR)'].agg(
    Total_Sales='sum',
    Product_Count='count',
    Average_Price_Per_Size='mean'
).sort_values(by='Total_Sales', ascending=False)
Resolution_summary
# Out:
#             Total_Sales  Product_Count  Average_Price_Per_Size
# Resolution
# 4K          33766833.00            376                89805.41
# HD READY     1529951.00            108                14166.21
# FULL HD      1088505.00             53                20537.83

# %% [markdown]
# ### 🖥️ TV Resolution-wise Sales Summary
#
# This table presents a summary of TV sales segmented by screen resolution, including total revenue, number of products sold, and average price:
#
# | Resolution | 💰 Total Sales (INR) | 📦 Product Count | 💵 Average Price |
# |------------|----------------------|------------------|------------------|
# | **4K**     | ₹33,766,833          | 376              | ₹89,805          |
# | **HD READY** | ₹1,529,951         | 108              | ₹14,166          |
# | **FULL HD**  | ₹1,088,505         | 53               | ₹20,538          |
#
# #### Insights:
# - **4K TVs dominate** the market in terms of revenue and volume, contributing over **33 million INR** in total sales.
# - **HD READY TVs** are popular in quantity but have significantly lower average prices.
# - **FULL HD TVs** are the least sold but priced moderately higher than HD READY TVs.
#
# This analysis highlights a **clear shift in consumer preference toward higher resolution (4K)** TVs, suggesting a trend toward premium quality displays.

# %%
# Create a combined category: "<Size>" - <Resolution>
df_tv['Size_Resolution_Category'] = df_tv['Size (Inch)'].astype(str) + '" - ' + df_tv['Resolution']

# Group by the new combined column
category_summary = df_tv.groupby('Size_Resolution_Category')['Selling Price (INR)'].agg(
    Total_Sales='sum',
    Product_Count='count',
    Average_Price='mean'
).sort_values(by='Total_Sales', ascending=False)

# Optionally round average price for readability
category_summary['Average_Price'] = category_summary['Average_Price'].round(0).astype(int)

# Size-Resoltion combinations where number of TVs are more than 10 for each combination
category_summary = category_summary[category_summary['Product_Count'] >= 10]
category_summary
# Out:
# C:\Users\saikiran\AppData\Local\Temp\ipykernel_15356\3131801294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tv['Size_Resolution_Category'] = df_tv['Size (Inch)'].astype(str) + '" - ' + df_tv['Resolution']
#                           Total_Sales  Product_Count  Average_Price
# Size_Resolution_Category
# 65.0" - 4K                 8217446.00             75         109566
# 55.0" - 4K                 6236100.00            106          58831
# 75.0" - 4K                 4979725.00             32         155616
# 85.0" - 4K                 3801504.00             11         345591
# 43.0" - 4K                 2688728.00             80          33609
# 50.0" - 4K                 2162107.00             52          41579
# ...

# %% [markdown]
# ### 📊 TV Sales by Size & Resolution – Summary
#
# This table shows how screen **size** and **resolution** impact TV sales performance.
#
# ---
#
# ### 🔍 Key Takeaways:
#
# - **Top Seller**: `65" - 4K` leads in total sales (₹8.2M) with a high average price.
# - **Most Options**: `55" - 4K` has the most models (106), making it widely available.
# - **Premium Segment**: `85" - 4K` has the highest average price (₹345K) despite fewer products.
# - **Budget Picks**: `32" - HD READY` and `40" - FULL HD` are low-cost, high-volume options.
# - **Popular Mid-Range**: `43" - 4K` and `50" - 4K` balance price and product count well.
#
# ---
#
# ### 📌 Business Use
#
# Useful for targeting:
#
# - **High-end buyers** → Larger 4K TVs
# - **Mass-market** → Budget 32"-43" TVs
# - **Inventory planning** → Focus on popular size-res combos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Reset index if needed
if category_summary.index.name is not None:
    category_summary = category_summary.reset_index()

# Set seaborn theme but turn off grid
sns.set_theme(style="white")

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(14, 7))

# Bar plot for Total Sales
bars = ax1.bar(
    category_summary["Size_Resolution_Category"],
    category_summary["Total_Sales"],
    color="#4682B4",
    width=0.6,
    label="Total Sales"
)
ax1.set_ylabel("Total Sales (INR)", color="#4682B4", fontsize=12)
ax1.tick_params(axis='y', labelcolor="#4682B4")
ax1.set_xticks(range(len(category_summary)))
ax1.set_xticklabels(category_summary["Size_Resolution_Category"], rotation=45, ha='right', fontsize=10)

# Remove inner gridlines
ax1.grid(False)

# Product Count (secondary Y axis)
ax2 = ax1.twinx()
ax2.plot(
    range(len(category_summary)),
    category_summary["Product_Count"].values,
    color="#E27D60",
    marker='o',
    linewidth=2,
    label="Product Count"
)
ax2.set_ylabel("Product Count", color="#E27D60", fontsize=12)
ax2.tick_params(axis='y', labelcolor="#E27D60")
ax2.grid(False)

# Average Price (third axis)
ax3 = ax1.twinx()
ax3.spines["right"].set_position(("outward", 70))
ax3.plot(
    range(len(category_summary)),
    category_summary["Average_Price"].values,
    color="#6AB187",
    marker='s',
    linestyle="--",
    linewidth=2,
    label="Average Price"
)
ax3.set_ylabel("Average Price (INR)", color="#6AB187", fontsize=12)
ax3.tick_params(axis='y', labelcolor="#6AB187")
ax3.grid(False)

# Annotations
for i in range(len(category_summary)):
    ax1.text(i, category_summary["Total_Sales"][i] + 400000, f"₹{int(category_summary['Total_Sales'][i]):,}",
             ha='center', va='bottom', fontsize=9, color="#000000")
    ax2.text(i, category_summary["Product_Count"][i] + 2, f"{int(category_summary['Product_Count'][i])}",
             ha='center', va='bottom', fontsize=9, color="#E27D60")
    ax3.text(i, category_summary["Average_Price"][i] - 15000, f"₹{int(category_summary['Average_Price'][i]):,}",
             ha='center', va='bottom', fontsize=9, color="#0C0C0C")

# Final touches
plt.title("TV Sales by Size-Resolution Category", fontsize=16, weight='bold')
fig.tight_layout(rect=[0, 0, 1, 0.95])

# Combined legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
ax1.legend(lines1 + lines2 + lines3, labels1 + labels2 + labels3, loc='upper center', ncol=3, frameon=False)

plt.show()

# %% [markdown]
# ### 📊 TV Sales by Size-Resolution Category – Chart Interpretation
#
# This visualization combines **bar and line plots** to showcase the relationship between **TV size-resolution categories** and three key metrics:
#
# ---
#
# #### 🔹 **1. Bar Chart (Blue): Total Sales (INR)**
# - The **height of the blue bars** represents the **total revenue generated** for each size-resolution category.
# - **65.0" - 4K TVs** lead with ₹8,217,446 in total sales.
# - Categories with lower total sales:
#   - **40.0" - FULL HD**: ₹185,848
#   - **43.0" - HD READY**: ₹297,414
#
# ---
#
# #### 🔸 **2. Line Plot (Orange): Product Count**
# - This line shows **how many unique TV products** were available in each category.
# - The **highest number of products**:
#   - **55.0" - 4K** with **106 products**.
# - The **lowest**:
#   - **85.0" - 4K** with only **11 products**.
#
# ---
#
# #### 🟢 **3. Line Plot (Green Dashed): Average Price**
# - Shows the **average price per product** in each category.
# - Highest average price:
#   - **85.0" - 4K**: ₹345,591
# - Lowest average price:
#   - **32.0" - HD READY**: ₹12,862
#   - **40.0" - FULL HD**: ₹16,895
#
# ---
#
# ### 🧠 Key Insights:
#
# - **High-end models (like 65" and 85" 4K)** drive massive sales despite fewer product variants due to their high prices.
# - **Mid-sized TVs (55", 50", 43")** strike a balance between **volume and price**.
# - **Smaller screens (32", 40")** are low-priced and low-volume, contributing less to total revenue.
