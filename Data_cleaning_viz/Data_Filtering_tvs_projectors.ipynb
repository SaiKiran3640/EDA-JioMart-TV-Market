# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv(r"D:\VS Python\venv-selenium\JIOMART\jiomart_tvs.csv", encoding='utf-8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              729 non-null    object
#  1   price_discounted  714 non-null    object
#  2   price_original    710 non-null    object
#  3   offer_percent     708 non-null    object
#  4   bank_offer        200 non-null    object
#  5   limited_time      98 non-null     object
#  6   position          729 non-null    int64
# dtypes: int64(1), object(6)
# memory usage: 40.0+ KB

# %%
df['bank_offer'] = df['bank_offer'].fillna('No Bank Offer')
df['bank_offer']
# Out:
# 0      Flat 5% Instant Discount On HDFC, ICICI, AXIS,...
# 1      Flat 5% Instant Discount On HDFC, ICICI, AXIS,...
# 2                                    Limited Offer Price
# 3      Flat 5% Instant Discount On HDFC, ICICI, AXIS,...
# 4                                          No Bank Offer
#                              ...
# 724                                        No Bank Offer
# 725                                        No Bank Offer
# 726       Instant Discount On HDFC, ICICI, AXIS, SBI CC*
# 727                                        No Bank Offer
# 728                                        No Bank Offer
# Name: bank_offer, Length: 729, dtype: object

# %%
# Extract details from 'name'
def extract_details(name):
    brand = name.split()[0]
    
    size_cm_match = re.search(r'(\d+(\.\d+)?)\s*cm', name)
    size_inch_match = re.search(r'\((\d+)\s*(inch|inches)?\)', name, re.IGNORECASE)
    resolution_match = re.search(r'\b(HD Ready|FHD|Full HD|UHD|4K)\b', name, re.IGNORECASE)
    
    size_cm = float(size_cm_match.group(1)) if size_cm_match else None
    size_inch = int(size_inch_match.group(1)) if size_inch_match else None
    resolution = resolution_match.group(1).upper() if resolution_match else None

    if not resolution and size_inch == 32:
        resolution = "HD READY"
    elif not resolution:
        resolution = "Not Mentioned"

    if 'TV' in name.upper():
        category = 'Television'
    elif 'PROJECTOR' in name.upper():
        category = 'Projector'
    else:
        category = 'Others'

    return pd.Series({
        'brand': brand,
        'size_cm': size_cm,
        'size_inch': size_inch,
        'resolution': resolution,
        'category': category
    })

# ✅ Use concat instead of join to avoid index mismatch
extracted_df = df['name'].apply(extract_details)
df = pd.concat([df, extracted_df], axis=1)
df
# Out:
#                                                   name price_discounted  \
# 0    Redmi 81.28 cm (32 inch) Smart Fire TV, Black,...       ₹10,490.00
# 1    Foxsky 80 cm (32 inch) HD Ready LED Smart TV, ...        ₹6,999.00
# 2    Samsung wondertainment 80 cm (32 Inch) HD Read...       ₹14,490.00
# 3    Samsung 108 cm (43 Inch) 4K Ultra HD Smart TV ...       ₹28,990.00
# 4    Hespa Mini Projector LED Home Theater with Rem...        ₹1,299.00
# ..                                                 ...              ...
# 724  NVY 127 cm (50 Inch) UHD Smart Frameless LED T...       ₹49,900.00
# 725  Itel 80 cm (32 inch) HD Ready Smart LED TV, G ...       ₹10,999.00
# 726  Kodak 126 cm (50 inch) Ultra HD (4K) LED Smart...       ₹27,498.00
# 727                 ANKER Nebula Apollo Home Projector       ₹37,999.00
# 728       LG 109.2 cm (43 Inch) 4K UHD TV, 43UA83506LA       ₹43,340.00
#
#     price_original offer_percent  \
# 0       ₹24,999.00       58% OFF
# 1       ₹20,999.00       66% OFF
# 2       ₹18,990.00       23% OFF
# 3       ₹44,900.00       35% OFF
# 4        ₹2,999.00       56% OFF
# ..             ...           ...
# 724            NaN           NaN
# 725     ₹22,990.00       52% OFF
# 726     ₹33,999.00       19% OFF
# 727     ₹39,999.00        5% OFF
# 728     ₹52,990.00       18% OFF
#
#                                             bank_offer       limited_time  \
# 0    Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  Limited Time Deal
# 1    Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  Limited Time Deal
# 2                                  Limited Offer Price  Limited Time Deal
# 3    Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  Limited Time Deal
# 4                                        No Bank Offer                NaN
# ..                                                 ...                ...
# 724                                      No Bank Offer                NaN
# 725                                      No Bank Offer                NaN
# 726     Instant Discount On HDFC, ICICI, AXIS, SBI CC*                NaN
# 727                                      No Bank Offer                NaN
# 728                                      No Bank Offer                NaN
#
#      position    brand  size_cm  size_inch     resolution    category
# 0           1    Redmi    81.28       32.0       HD READY  Television
# 1           2   Foxsky    80.00       32.0       HD READY  Television
# 2           3  Samsung    80.00       32.0       HD READY  Television
# 3           4  Samsung   108.00       43.0             4K  Television
# 4           5    Hespa      NaN        NaN  Not Mentioned   Projector
# ..        ...      ...      ...        ...            ...         ...
# 724       740      NVY   127.00       50.0            UHD  Television
# 725       741     Itel    80.00       32.0       HD READY  Television
# 726       742    Kodak   126.00       50.0             4K  Television
# 727       743    ANKER      NaN        NaN  Not Mentioned   Projector
# 728       744       LG   109.20       43.0             4K  Television
#
# [729 rows x 12 columns]

# %%
df['price_discounted(INR)'] = df['price_discounted'].str.replace('₹', '', regex=False).str.replace(',', '').astype(float)
df['price_original(INR)'] = df['price_original'].str.replace('₹', '', regex=False).str.replace(',', '').astype(float)



# Rename 'offer_percent' to 'discount(%)' and remove 'OFF'
df = df.rename(columns={'offer_percent': 'discount(%)'})
#df['discount(%)'] = df['discount(%)'].str.replace('% OFF', '', regex=False).astype(int)

# %%
df['discount(%)'] = (
    df['discount(%)']
    .str.replace('% OFF', '', regex=False)
    .fillna(0)
    .astype(int)
)

# %%
df = df.rename(columns={
    'name': 'Name of the Product',
    'category': 'Product Type',
    'brand': 'Brand Name',
    'price_discounted(INR)': 'Selling Price (INR)',
    'price_original(INR)': 'Original Price (INR)',
    'size_inch': 'Size (Inch)',
    'size_cm': 'Size (cm)',
    'resolution': 'Resolution',
    'discount(%)': 'Discount (%)',
    'bank_offer': 'Bank Offer',
    'limited_time': 'Limited Time Deal'
})
# Reorder columns
df = df[['Name of the Product', 'Brand Name', 'Product Type', 'Size (Inch)', 'Size (cm)', 
         'Resolution', 'Selling Price (INR)', 'Original Price (INR)', 
         'Discount (%)', 'Bank Offer', 'Limited Time Deal']]

# %%
df = df[['Name of the Product', 'Brand Name', 'Product Type', 'Selling Price (INR)','Original Price (INR)','Size (Inch)', 'Size (cm)', 
         'Resolution','Discount (%)', 'Bank Offer', 'Limited Time Deal']]

# %%
df
# Out:
#                                    Name of the Product Brand Name  \
# 0    Redmi 81.28 cm (32 inch) Smart Fire TV, Black,...      Redmi
# 1    Foxsky 80 cm (32 inch) HD Ready LED Smart TV, ...     Foxsky
# 2    Samsung wondertainment 80 cm (32 Inch) HD Read...    Samsung
# 3    Samsung 108 cm (43 Inch) 4K Ultra HD Smart TV ...    Samsung
# 4    Hespa Mini Projector LED Home Theater with Rem...      Hespa
# ..                                                 ...        ...
# 724  NVY 127 cm (50 Inch) UHD Smart Frameless LED T...        NVY
# 725  Itel 80 cm (32 inch) HD Ready Smart LED TV, G ...       Itel
# 726  Kodak 126 cm (50 inch) Ultra HD (4K) LED Smart...      Kodak
# 727                 ANKER Nebula Apollo Home Projector      ANKER
# 728       LG 109.2 cm (43 Inch) 4K UHD TV, 43UA83506LA         LG
#
#     Product Type  Selling Price (INR)  Original Price (INR)  Size (Inch)  \
# 0     Television              10490.0               24999.0         32.0
# 1     Television               6999.0               20999.0         32.0
# 2     Television              14490.0               18990.0         32.0
# 3     Television              28990.0               44900.0         43.0
# 4      Projector               1299.0                2999.0          NaN
# ..           ...                  ...                   ...          ...
# 724   Television              49900.0                   NaN         50.0
# 725   Television              10999.0               22990.0         32.0
# 726   Television              27498.0               33999.0         50.0
# 727    Projector              37999.0               39999.0          NaN
# 728   Television              43340.0               52990.0         43.0
#
#      Size (cm)     Resolution  Discount (%)  \
# 0        81.28       HD READY            58
# 1        80.00       HD READY            66
# 2        80.00       HD READY            23
# 3       108.00             4K            35
# 4          NaN  Not Mentioned            56
# ..         ...            ...           ...
# 724     127.00            UHD             0
# 725      80.00       HD READY            52
# 726     126.00             4K            19
# 727        NaN  Not Mentioned             5
# 728     109.20             4K            18
#
#                                             Bank Offer  Limited Time Deal
# 0    Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  Limited Time Deal
# 1    Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  Limited Time Deal
# 2                                  Limited Offer Price  Limited Time Deal
# 3    Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  Limited Time Deal
# 4                                        No Bank Offer                NaN
# ..                                                 ...                ...
# 724                                      No Bank Offer                NaN
# 725                                      No Bank Offer                NaN
# 726     Instant Discount On HDFC, ICICI, AXIS, SBI CC*                NaN
# 727                                      No Bank Offer                NaN
# 728                                      No Bank Offer                NaN
#
# [729 rows x 11 columns]

# %%
df.to_csv("jiomart_tvs2.csv", index=False)

# %%
df.info()
# Display the first few rows of the DataFrame
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   729 non-null    object
#  1   Brand Name            729 non-null    object
#  2   Product Type          729 non-null    object
#  3   Selling Price (INR)   714 non-null    float64
#  4   Original Price (INR)  710 non-null    float64
#  5   Size (Inch)           503 non-null    float64
#  6   Size (cm)             517 non-null    float64
#  7   Resolution            729 non-null    object
#  8   Discount (%)          729 non-null    int64
#  9   Bank Offer            729 non-null    object
#  10  Limited Time Deal     98 non-null     object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 62.8+ KB
#                                  Name of the Product Brand Name Product Type  \
# 0  Redmi 81.28 cm (32 inch) Smart Fire TV, Black,...      Redmi   Television
# 1  Foxsky 80 cm (32 inch) HD Ready LED Smart TV, ...     Foxsky   Television
# 2  Samsung wondertainment 80 cm (32 Inch) HD Read...    Samsung   Television
# 3  Samsung 108 cm (43 Inch) 4K Ultra HD Smart TV ...    Samsung   Television
# 4  Hespa Mini Projector LED Home Theater with Rem...      Hespa    Projector
#
#    Selling Price (INR)  Original Price (INR)  Size (Inch)  Size (cm)  \
# 0              10490.0               24999.0         32.0      81.28
# 1               6999.0               20999.0         32.0      80.00
# 2              14490.0               18990.0         32.0      80.00
# 3              28990.0               44900.0         43.0     108.00
# 4               1299.0                2999.0          NaN        NaN
#
#       Resolution  Discount (%)  \
# 0       HD READY            58
# 1       HD READY            66
# 2       HD READY            23
# 3             4K            35
# 4  Not Mentioned            56
#
#                                           Bank Offer  Limited Time Deal
# 0  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  Limited Time Deal
# 1  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  Limited Time Deal
# 2                                Limited Offer Price  Limited Time Deal
# 3  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  Limited Time Deal
# 4                                      No Bank Offer                NaN

# %%
df['Limited Time Deal'] = df['Limited Time Deal'].fillna('No Limited Time Deal')
df['Original Price (INR)'] = df['Original Price (INR)'].fillna(df['Selling Price (INR)'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   729 non-null    object
#  1   Brand Name            729 non-null    object
#  2   Product Type          729 non-null    object
#  3   Selling Price (INR)   714 non-null    float64
#  4   Original Price (INR)  714 non-null    float64
#  5   Size (Inch)           503 non-null    float64
#  6   Size (cm)             517 non-null    float64
#  7   Resolution            729 non-null    object
#  8   Discount (%)          729 non-null    int64
#  9   Bank Offer            729 non-null    object
#  10  Limited Time Deal     729 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 62.8+ KB

# %%
df[df.isna().any(axis=1)]
# Out:
#                                    Name of the Product Brand Name  \
# 4    Hespa Mini Projector LED Home Theater with Rem...      Hespa
# 14   Hespa Mini Projector LED Home Theater with Rem...      Hespa
# 36   Hespa Portable Mini Projector LED Home Theater...      Hespa
# 39   Hespa YG-300 HD Smart Mini Movie Projector LED...      Hespa
# 40   Hespa Full HD Mini Projector LED Home Theater ...      Hespa
# ..                                                 ...        ...
# 719  SFZ Mini Smart Projector for Home, Native 720p...        SFZ
# 720  SFZ 1280x1080P 2K LCD LED 180 Rotation Portabl...        SFZ
# 721  SFZ Portable Mini Projector, 4K 1080P Full HD ...        SFZ
# 722  SFZ 4K & 1080p Support, 270 Degree Rotatable P...        SFZ
# 727                 ANKER Nebula Apollo Home Projector      ANKER
#
#     Product Type  Selling Price (INR)  Original Price (INR)  Size (Inch)  \
# 4      Projector               1299.0                2999.0          NaN
# 14     Projector               1299.0                2999.0          NaN
# 36     Projector               1299.0                2999.0          NaN
# 39     Projector               1299.0                2999.0          NaN
# 40     Projector               1399.0                2999.0          NaN
# ..           ...                  ...                   ...          ...
# 719    Projector                  NaN                   NaN          NaN
# 720    Projector                  NaN                   NaN          NaN
# 721    Projector                  NaN                   NaN          NaN
# 722    Projector                  NaN                   NaN          NaN
# 727    Projector              37999.0               39999.0          NaN
#
#      Size (cm)     Resolution  Discount (%)     Bank Offer  \
# 4          NaN  Not Mentioned            56  No Bank Offer
# 14         NaN  Not Mentioned            56  No Bank Offer
# 36         NaN  Not Mentioned            56  No Bank Offer
# 39         NaN  Not Mentioned            56  No Bank Offer
# 40         NaN        FULL HD            53  No Bank Offer
# ..         ...            ...           ...            ...
# 719        NaN             4K             0  No Bank Offer
# 720        NaN  Not Mentioned             0  No Bank Offer
# 721        NaN             4K             0  No Bank Offer
# 722        NaN             4K             0  No Bank Offer
# 727        NaN  Not Mentioned             5  No Bank Offer
#
#         Limited Time Deal
# 4    No Limited Time Deal
# 14   No Limited Time Deal
# 36   No Limited Time Deal
# 39   No Limited Time Deal
# 40   No Limited Time Deal
# ..                    ...
# 719  No Limited Time Deal
# 720  No Limited Time Deal
# 721  No Limited Time Deal
# 722  No Limited Time Deal
# 727  No Limited Time Deal
#
# [226 rows x 11 columns]

# %%
df_tvs = df[df['Product Type'] == 'Television']
df_tvs.info()
df_tvs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 553 entries, 0 to 728
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   553 non-null    object
#  1   Brand Name            553 non-null    object
#  2   Product Type          553 non-null    object
#  3   Selling Price (INR)   553 non-null    float64
#  4   Original Price (INR)  553 non-null    float64
#  5   Size (Inch)           501 non-null    float64
#  6   Size (cm)             514 non-null    float64
#  7   Resolution            553 non-null    object
#  8   Discount (%)          553 non-null    int64
#  9   Bank Offer            553 non-null    object
#  10  Limited Time Deal     553 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 51.8+ KB
#                                  Name of the Product Brand Name Product Type  \
# 0  Redmi 81.28 cm (32 inch) Smart Fire TV, Black,...      Redmi   Television
# 1  Foxsky 80 cm (32 inch) HD Ready LED Smart TV, ...     Foxsky   Television
# 2  Samsung wondertainment 80 cm (32 Inch) HD Read...    Samsung   Television
# 3  Samsung 108 cm (43 Inch) 4K Ultra HD Smart TV ...    Samsung   Television
# 5  LG 139.7 cm (55 inch) Ultra HD (4K) LED Smart ...         LG   Television
#
#    Selling Price (INR)  Original Price (INR)  Size (Inch)  Size (cm)  \
# 0              10490.0               24999.0         32.0      81.28
# 1               6999.0               20999.0         32.0      80.00
# 2              14490.0               18990.0         32.0      80.00
# 3              28990.0               44900.0         43.0     108.00
# 5              41990.0               86990.0         55.0     139.70
#
#   Resolution  Discount (%)                                         Bank Offer  \
# 0   HD READY            58  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...
# 1   HD READY            66  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...
# 2   HD READY            23                                Limited Offer Price
# 3         4K            35  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...
# 5         4K            51                                Limited Offer Price
#
#    Limited Time Deal
# 0  Limited Time Deal
# 1  Limited Time Deal
# 2  Limited Time Deal
# 3  Limited Time Deal
# 5  Limited Time Deal

# %%
df_projectors = df[df['Product Type'] == 'Projector']

df_projectors = df_projectors[['Name of the Product', 'Brand Name', 'Selling Price (INR)', 'Original Price (INR)', 'Resolution', 'Discount (%)', 'Bank Offer', 'Limited Time Deal']]
df_projectors.bfill(inplace=True)

df_projectors.info()
df_projectors.groupby('Brand Name').size().sort_values(ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 4 to 727
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   165 non-null    object
#  1   Brand Name            165 non-null    object
#  2   Selling Price (INR)   165 non-null    float64
#  3   Original Price (INR)  165 non-null    float64
#  4   Resolution            165 non-null    object
#  5   Discount (%)          165 non-null    int64
#  6   Bank Offer            165 non-null    object
#  7   Limited Time Deal     165 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 11.6+ KB
# Brand Name
# mPix           24
# Hespa          20
# eKus           18
# ZuZu,          14
# IBS            13
# Tart            9
# Omex            7
# Tonzo           6
# SFZ             5
# TONZO           4
# METRONAUT       3
# YOTON           3
# Trigent         3
# XElectron       3
# Lazervision     3
# Ekus            3
# Total           2
# KSBOY           2
# PIXPAQ          2
# BenQ            2
# VilenRay        2
# ANKER           1
# CLEGO           1
# Balliatic       1
# Ausha           1
# AUSHA           1
# Formovie        1
# Prime           1
# Pixpaq          1
# E               1
# RFV1            1
# WZATCO          1
# The             1
# Torexo          1
# Wanbo           1
# X               1
# amiciVision     1
# Zuzu            1
# dtype: int64

# %%
df_projectors["Brand Name"].unique()
# Out:
# array(['Hespa', 'eKus', 'Omex', 'mPix', 'Pixpaq', 'PIXPAQ', 'TONZO',
#        'Tonzo', 'XElectron', 'WZATCO', 'VilenRay', 'Formovie', 'KSBOY',
#        'IBS', 'AUSHA', 'Ekus', 'Prime', 'amiciVision', 'Trigent', 'YOTON',
#        'METRONAUT', 'Total', 'ZuZu,', 'RFV1', 'Lazervision', 'CLEGO',
#        'Torexo', 'Balliatic', 'X', 'Wanbo', 'BenQ', 'Ausha', 'E', 'Tart',
#        'Zuzu', 'The', 'SFZ', 'ANKER'], dtype=object)

# %%
df_projectors["Brand Name"].replace("E", "E Gate" , inplace=True)
df_projectors["Brand Name"].replace("The", "The Intact Boon" , inplace=True)
df_projectors["Brand Name"].replace("X", "X Electron" , inplace=True)
# Out:
# C:\Users\saikiran\AppData\Local\Temp\ipykernel_26668\4178934434.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_projectors["Brand Name"].replace("E", "E Gate" , inplace=True)
# C:\Users\saikiran\AppData\Local\Temp\ipykernel_26668\4178934434.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_projectors["Brand Name"].replace("The", "The Intact Boon" , inplace=True)
# C:\Users\saikiran\AppData\Local\Temp\ipykernel_26668\4178934434.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_projectors["Brand Name"].replace("X", "X Electron" , inplace=True)

# %%
df_projectors["Brand Name"].unique()
# Out:
# array(['Hespa', 'eKus', 'Omex', 'mPix', 'Pixpaq', 'PIXPAQ', 'TONZO',
#        'Tonzo', 'XElectron', 'WZATCO', 'VilenRay', 'Formovie', 'KSBOY',
#        'IBS', 'AUSHA', 'Ekus', 'Prime', 'amiciVision', 'Trigent', 'YOTON',
#        'METRONAUT', 'Total', 'ZuZu,', 'RFV1', 'Lazervision', 'CLEGO',
#        'Torexo', 'Balliatic', 'X Electron', 'Wanbo', 'BenQ', 'Ausha',
#        'E Gate', 'Tart', 'Zuzu', 'The Intact Boon', 'SFZ', 'ANKER'],
#       dtype=object)

# %%
df_projectors.to_csv("jiomart_projectors.csv", index=False)

# %%
df_tvs_nan = df_tvs[df_tvs.isna().any(axis=1) == True].reset_index(drop=False)

df_tvs_nan.iloc[1:2, df_tvs_nan.columns.get_loc('Product Type')] = 'Projector'
df_tvs_nan.iloc[23:32, df_tvs_nan.columns.get_loc('Product Type')] = 'Projector'
df_tvs_nan.iloc[42:46, df_tvs_nan.columns.get_loc('Product Type')] = 'Projector'

df_p2 = df_tvs_nan[df_tvs_nan["Product Type"] == "Projector"]
df_p2
df_tvs_nan
# Out:
#     index                                Name of the Product Brand Name  \
# 0      68  PIXPAQ OG Pro (JAPAN), Extreme Bright 1400 ANS...     PIXPAQ
# 1     115  Willen 600 Lumens 1080 P Mini Portable Mini Pr...     Willen
# 2     163  BPL 80 cm 32 (inch) HD Linux Smart TV with Dol...        BPL
# 3     164  BPL 80 cm 32 (inch) HD Linux Smart TV with Dol...        BPL
# 4     240    Haier 139.7 cm QLED Google Smart TV, Grey, 55Q6      Haier
# 5     241  Haier 165 cm 4K UHD Google Smart TV, Black, M65UG      Haier
# 6     242      Haier 109 cm QLED Google Smart TV, Grey, 43Q6      Haier
# 7     243      Haier 109 cm QLED Google Smart TV, Grey, 65Q6      Haier
# 8     292  TCL 75P635 75 inch (189 cm) 4K Ultra HD LED An...        TCL
# 9     293          Samsung 55 Neo QLED Smart LED TV, 55QN95C    Samsung
# 10    294          Samsung 50 Neo QLED Smart LED TV, 50QN90C    Samsung
# 11    295            Samsung 85 Neo QLED 8K LED TV, 85QN900C    Samsung
# 12    303         TCL 32 Full HD Smart Android TV, 32S5403AF        TCL
# 13    304                TCL 50 QLED Smart Google TV, 50C645        TCL
# 14    305          TCL 55 4K UHD Smart Google TV, 55P635 PRO        TCL
# 15    306          TCL 50 4K UHD Smart Google TV, 50P635 PRO        TCL
# 16    390  MI 32 HD Ready Smart LED TV, 4A Horizon, ELA45...         MI
# 17    409  TELESTONE 65" 4K UHD Smart LED TV | Smart TV |...  TELESTONE
# 18    410  TELESTONE 43" 4K UHD LED TV | Cloud Android Sm...  TELESTONE
# 19    411  TELESTONE 43" Full HD LED TV | Smart TV | Beze...  TELESTONE
# 20    412  TELESTONE 32" HD Ready LED TV | Smart Android ...  TELESTONE
# 21    413  TELESTONE 32" HD Ready Lite LED TV | Smart And...  TELESTONE
# 22    414  TELESTONE 32" GTV Smart LED TV | Smart TV | Go...  TELESTONE
# 23    472  Trigent Andriod 5G WiFi Projector Home 4K Supp...    Trigent
# 24    474  YOTON Andriod 5G WiFi Projector Home 4K Suppor...      YOTON
# 25    479  Trigent Andriod 5G WiFi Projector Home 4K Supp...    Trigent
# 26    480  Total Andriod 5G WiFi Projector Home 4K Suppor...      Total
# 27    482  METRONAUT Andriod 5G WiFi Projector Home 4K Su...  METRONAUT
# 28    483  Total Andriod 5G WiFi Projector Home 4K Suppor...      Total
# 29    489  Total Mini ANDRIOD Projector for Home 4K Suppo...      Total
# 30    494  Omex Upgrade Version Advance YouTube DLNA TV W...       Omex
# 31    511  Torexo Sales T10 Full HD 1920*1080P Android Pr...     Torexo
# 32    538  Bush 40 inch (100 cm) FHD Smart LED TV, Black,...       Bush
# 33    539  Bush 43 inch (109 cm) FHD Smart LED TV, Black,...       Bush
# 34    549  Haier 139.7 cm 4K UHD Google Smart TV, Black, ...      Haier
# 35    557          Samsung 65 Neo QLED Smart LED TV, 65QN85C    Samsung
# 36    558          Samsung 85 Neo QLED Smart LED TV, 85QN90C    Samsung
# 37    563          TCL 65 4K UHD Smart Google TV, 65P635 PRO        TCL
# 38    568  Telestone 50-inch 4K UHD Frameless Smart LED T...  Telestone
# 39    569  TELESTONE 55" 4K UHD Smart LED TV | Smart TV |...  TELESTONE
# 40    570  Telestone 75-Inch UHD 4K Frameless Smart LED T...  Telestone
# 41    572  TELESTONE 43" GTV Smart LED TV | Smart TV | Go...  TELESTONE
# 42    590  YOTON Andriod 5G WiFi Projector Home 4K Suppor...      YOTON
# 43    596  ZuZu, move for more better. 3D Full HD LED Pro...      ZuZu,
# 44    604  IBS Mini ANDRIOD Projector for Home 4K Support...        IBS
# 45    605  METRONAUT Mini ANDRIOD Projector for Home 4K S...  METRONAUT
# 46    613  ZuZu, move for more better. 2000 Lumen Portabl...      ZuZu,
# 47    646  Bush 32 inch (80 cm) HD Smart LED TV, Black, J...       Bush
# 48    647  Bush 24 inch (60 cm) HD Normal LED TV, Black, ...       Bush
# 49    677  Bush 50 inch (127 cm) 4K UHD Smart LED TV, Bla...       Bush
# 50    705          TCL 75 4K UHD Smart Google TV, 75P635 PRO        TCL
# 51    716          Samsung 65 Neo QLED Smart LED TV, 65QN95C    Samsung
#
#    Product Type  Selling Price (INR)  Original Price (INR)  Size (Inch)  \
# 0    Television              22999.0               26999.0          NaN
# 1     Projector               2450.0                4999.0          NaN
# 2    Television              11999.0               18500.0          NaN
# 3    Television              11999.0               18500.0          NaN
# 4    Television              55990.0               99990.0          NaN
# 5    Television              64990.0              110990.0          NaN
# 6    Television              38590.0               69990.0          NaN
# 7    Television              78989.0              135990.0          NaN
# 8    Television              60990.0              254990.0          NaN
# 9    Television             139988.0              244900.0          NaN
# 10   Television              84989.0              164900.0          NaN
# 11   Television             849990.0             1549900.0          NaN
# 12   Television              12989.0               20990.0          NaN
# 13   Television              32990.0              114990.0          NaN
# 14   Television              45989.0               79990.0          NaN
# 15   Television              30990.0               66990.0          NaN
# 16   Television              12989.0               19999.0          NaN
# 17   Television              59990.0               60990.0          NaN
# 18   Television              23990.0               24990.0          NaN
# 19   Television              18990.0               19990.0          NaN
# 20   Television              11990.0               12990.0          NaN
# 21   Television              10490.0               11490.0          NaN
# 22   Television              13990.0               14990.0          NaN
# 23    Projector               7599.0               19999.0          NaN
# 24    Projector               7599.0               15999.0          NaN
# 25    Projector               6649.0               14999.0          NaN
# 26    Projector               6649.0               14999.0          NaN
# 27    Projector               7599.0               19999.0          NaN
# 28    Projector               7599.0               19999.0          NaN
# 29    Projector               7599.0               19999.0          NaN
# 30    Projector               4990.0               14900.0          NaN
# 31    Projector              12299.0               21999.0          NaN
# 32   Television              11999.0               24999.0          NaN
# 33   Television              14999.0               28999.0          NaN
# 34   Television              43989.0               75990.0          NaN
# 35   Television             144990.0              249900.0          NaN
# 36   Television             499988.0              799900.0          NaN
# 37   Television              59990.0              126990.0          NaN
# 38   Television              34990.0               35990.0          NaN
# 39   Television              39990.0               40990.0          NaN
# 40   Television             109990.0              110990.0          NaN
# 41   Television              23990.0               24990.0          NaN
# 42    Projector               7599.0               19999.0          NaN
# 43    Projector              14500.0               29999.0          NaN
# 44    Projector               7599.0               19999.0          NaN
# 45    Projector               7599.0               19999.0          NaN
# 46   Television               9475.0               19999.0          NaN
# 47   Television               7999.0               17999.0          NaN
# 48   Television               6499.0               13999.0          NaN
# 49   Television              25999.0               40999.0          NaN
# 50   Television              79990.0              256990.0          NaN
# 51   Television             150000.0              329900.0          NaN
#
#     Size (cm)     Resolution  Discount (%)  \
# 0         NaN  Not Mentioned            14
# 1         NaN  Not Mentioned            50
# 2        80.0  Not Mentioned            35
# 3        80.0  Not Mentioned            35
# 4       139.7  Not Mentioned            44
# 5       165.0             4K            41
# 6       109.0  Not Mentioned            44
# 7       109.0  Not Mentioned            41
# 8       189.0             4K            76
# 9         NaN  Not Mentioned            42
# 10        NaN  Not Mentioned            48
# 11        NaN  Not Mentioned            45
# 12        NaN        FULL HD            38
# 13        NaN  Not Mentioned            71
# 14        NaN             4K            42
# 15        NaN             4K            53
# 16        NaN       HD READY            35
# 17        NaN             4K             1
# 18        NaN             4K             4
# 19        NaN        FULL HD             5
# 20        NaN       HD READY             7
# 21        NaN       HD READY             8
# 22        NaN       HD READY             6
# 23        NaN             4K            62
# 24        NaN             4K            52
# 25        NaN             4K            55
# 26        NaN             4K            55
# 27        NaN             4K            62
# 28        NaN             4K            62
# 29        NaN             4K            62
# 30        NaN  Not Mentioned            66
# 31        NaN        FULL HD            44
# 32      100.0            FHD            52
# 33      109.0            FHD            48
# 34      139.7             4K            42
# 35        NaN  Not Mentioned            41
# 36        NaN  Not Mentioned            37
# 37        NaN             4K            52
# 38        NaN             4K             2
# 39        NaN             4K             2
# 40        NaN            UHD             0
# 41        NaN        FULL HD             4
# 42        NaN             4K            62
# 43        NaN        FULL HD            51
# 44        NaN             4K            62
# 45        NaN             4K            62
# 46        NaN  Not Mentioned            52
# 47       80.0  Not Mentioned            55
# 48       60.0  Not Mentioned            53
# 49      127.0             4K            36
# 50        NaN             4K            68
# 51        NaN  Not Mentioned            54
#
#                                            Bank Offer     Limited Time Deal
# 0                                       No Bank Offer  No Limited Time Deal
# 1                                       No Bank Offer  No Limited Time Deal
# 2   Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 3   Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 4   Flat 12.5% Instant Discount On HDFC, ICICI, AX...  No Limited Time Deal
# 5   Flat 12.5% Instant Discount On HDFC, ICICI, AX...  No Limited Time Deal
# 6   Flat 12.5% Instant Discount On HDFC, ICICI, AX...  No Limited Time Deal
# 7   Flat 12.5% Instant Discount On HDFC, ICICI, AX...  No Limited Time Deal
# 8                                       No Bank Offer  No Limited Time Deal
# 9                                       No Bank Offer  No Limited Time Deal
# 10                                      No Bank Offer  No Limited Time Deal
# 11                                      No Bank Offer  No Limited Time Deal
# 12                                      No Bank Offer  No Limited Time Deal
# 13                                      No Bank Offer  No Limited Time Deal
# 14     Instant Discount On HDFC, ICICI, AXIS, SBI CC*  No Limited Time Deal
# 15                                      No Bank Offer  No Limited Time Deal
# 16                                      No Bank Offer  No Limited Time Deal
# 17                                      No Bank Offer  No Limited Time Deal
# 18                                      No Bank Offer  No Limited Time Deal
# 19                                      No Bank Offer  No Limited Time Deal
# 20                                      No Bank Offer  No Limited Time Deal
# 21                                      No Bank Offer  No Limited Time Deal
# 22                                      No Bank Offer  No Limited Time Deal
# 23                                      No Bank Offer  No Limited Time Deal
# 24                                      No Bank Offer  No Limited Time Deal
# 25                                      No Bank Offer  No Limited Time Deal
# 26                                      No Bank Offer  No Limited Time Deal
# 27                                      No Bank Offer  No Limited Time Deal
# 28                                      No Bank Offer  No Limited Time Deal
# 29                                      No Bank Offer  No Limited Time Deal
# 30                                      No Bank Offer  No Limited Time Deal
# 31                                      No Bank Offer  No Limited Time Deal
# 32  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 33  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 34  Flat 12.5% Instant Discount On HDFC, ICICI, AX...  No Limited Time Deal
# 35                                      No Bank Offer  No Limited Time Deal
# 36                                      No Bank Offer  No Limited Time Deal
# 37                                      No Bank Offer  No Limited Time Deal
# 38                                      No Bank Offer  No Limited Time Deal
# 39                                      No Bank Offer  No Limited Time Deal
# 40                                      No Bank Offer  No Limited Time Deal
# 41                                      No Bank Offer  No Limited Time Deal
# 42                                      No Bank Offer  No Limited Time Deal
# 43                                      No Bank Offer  No Limited Time Deal
# 44                                      No Bank Offer  No Limited Time Deal
# 45                                      No Bank Offer  No Limited Time Deal
# 46                                      No Bank Offer  No Limited Time Deal
# 47  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 48  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 49  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 50                                      No Bank Offer  No Limited Time Deal
# 51                                      No Bank Offer  No Limited Time Deal

# %%
# 1. Get NaN rows from df_tvs and retain their original index
df_tvs_nan = df_tvs[df_tvs.isna().any(axis=1)].copy()
df_tvs_nan = df_tvs_nan.reset_index()  # Keep original index in a column for later removal

# 2. Replace specific rows as Projectors
df_tvs_nan.loc[1:1, 'Product Type'] = 'Projector'
df_tvs_nan.loc[23:31, 'Product Type'] = 'Projector'
df_tvs_nan.loc[42:45, 'Product Type'] = 'Projector'

# 3. Get cleaned projector and TV rows
df_projectors = df_tvs_nan[df_tvs_nan["Product Type"] == "Projector"]
df_clean_tvs = df_tvs_nan[df_tvs_nan["Product Type"] == "Television"]

# 4. Drop original NaN rows from df_tvs using their old index
df_tvs_deduped = df_tvs.drop(index=df_tvs_nan['index'])

# 5. Drop the index column from cleaned nan data
df_tvs_nan.drop(columns=['index'], inplace=True)

# 6. Concatenate cleaned nan rows back to the deduplicated TV dataset
df_final = pd.concat([df_tvs_deduped, df_tvs_nan], ignore_index=True)

# 7. Optional: Check info
#f_tvs_deduped.info()
df_tvs_nan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[226], line 24
#      21 df_final = pd.concat([df_tvs_deduped, df_tvs_nan], ignore_index=True)
#      23 # 7. Optional: Check info
# ---> 24 d#f_tvs_deduped.info()
#      25 df_tvs_nan
#
# NameError: name 'd' is not defined

# %%
df_projectors1 = df_projectors.copy()


# Combine two DataFrames by stacking rows
combined_df = pd.concat([df_projectors1, df_p2], ignore_index=True)
combined_df = combined_df[['Name of the Product', 'Brand Name','Product Type','Selling Price (INR)', 'Original Price (INR)', 'Resolution', 'Discount (%)', 'Bank Offer', 'Limited Time Deal']]
combined_df["Resolution"].replace("Not Mentioned", "HD READY/FULL HD" , inplace=True)
combined_df['Product Type'] == "Projector"

combined_df['Product Type'] = combined_df['Product Type'].fillna('Projector')
# Out:
# C:\Users\saikiran\AppData\Local\Temp\ipykernel_26668\2094165170.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_df["Resolution"].replace("Not Mentioned", "HD READY/FULL HD" , inplace=True)

# %%
combined_df["Resolution"].unique()
# Out:
# array(['HD READY/FULL HD', '4K', 'FULL HD'], dtype=object)

# %%
combined_df.to_csv("jiomart_projectors_combined1.csv", index=False)

# %%
combined_df
# Out:
#                                   Name of the Product Brand Name Product Type  \
# 0   Willen 600 Lumens 1080 P Mini Portable Mini Pr...     Willen    Projector
# 1   Trigent Andriod 5G WiFi Projector Home 4K Supp...    Trigent    Projector
# 2   YOTON Andriod 5G WiFi Projector Home 4K Suppor...      YOTON    Projector
# 3   Trigent Andriod 5G WiFi Projector Home 4K Supp...    Trigent    Projector
# 4   Total Andriod 5G WiFi Projector Home 4K Suppor...      Total    Projector
# 5   METRONAUT Andriod 5G WiFi Projector Home 4K Su...  METRONAUT    Projector
# 6   Total Andriod 5G WiFi Projector Home 4K Suppor...      Total    Projector
# 7   Total Mini ANDRIOD Projector for Home 4K Suppo...      Total    Projector
# 8   Omex Upgrade Version Advance YouTube DLNA TV W...       Omex    Projector
# 9   Torexo Sales T10 Full HD 1920*1080P Android Pr...     Torexo    Projector
# 10  YOTON Andriod 5G WiFi Projector Home 4K Suppor...      YOTON    Projector
# 11  ZuZu, move for more better. 3D Full HD LED Pro...      ZuZu,    Projector
# 12  IBS Mini ANDRIOD Projector for Home 4K Support...        IBS    Projector
# 13  METRONAUT Mini ANDRIOD Projector for Home 4K S...  METRONAUT    Projector
# 14  Willen 600 Lumens 1080 P Mini Portable Mini Pr...     Willen    Projector
# 15  Trigent Andriod 5G WiFi Projector Home 4K Supp...    Trigent    Projector
# 16  YOTON Andriod 5G WiFi Projector Home 4K Suppor...      YOTON    Projector
# 17  Trigent Andriod 5G WiFi Projector Home 4K Supp...    Trigent    Projector
# 18  Total Andriod 5G WiFi Projector Home 4K Suppor...      Total    Projector
# 19  METRONAUT Andriod 5G WiFi Projector Home 4K Su...  METRONAUT    Projector
# 20  Total Andriod 5G WiFi Projector Home 4K Suppor...      Total    Projector
# 21  Total Mini ANDRIOD Projector for Home 4K Suppo...      Total    Projector
# 22  Omex Upgrade Version Advance YouTube DLNA TV W...       Omex    Projector
# 23  Torexo Sales T10 Full HD 1920*1080P Android Pr...     Torexo    Projector
# 24  YOTON Andriod 5G WiFi Projector Home 4K Suppor...      YOTON    Projector
# 25  ZuZu, move for more better. 3D Full HD LED Pro...      ZuZu,    Projector
# 26  IBS Mini ANDRIOD Projector for Home 4K Support...        IBS    Projector
# 27  METRONAUT Mini ANDRIOD Projector for Home 4K S...  METRONAUT    Projector
#
#     Selling Price (INR)  Original Price (INR)        Resolution  Discount (%)  \
# 0                2450.0                4999.0  HD READY/FULL HD            50
# 1                7599.0               19999.0                4K            62
# 2                7599.0               15999.0                4K            52
# 3                6649.0               14999.0                4K            55
# 4                6649.0               14999.0                4K            55
# 5                7599.0               19999.0                4K            62
# 6                7599.0               19999.0                4K            62
# 7                7599.0               19999.0                4K            62
# 8                4990.0               14900.0  HD READY/FULL HD            66
# 9               12299.0               21999.0           FULL HD            44
# 10               7599.0               19999.0                4K            62
# 11              14500.0               29999.0           FULL HD            51
# 12               7599.0               19999.0                4K            62
# 13               7599.0               19999.0                4K            62
# 14               2450.0                4999.0  HD READY/FULL HD            50
# 15               7599.0               19999.0                4K            62
# 16               7599.0               15999.0                4K            52
# 17               6649.0               14999.0                4K            55
# 18               6649.0               14999.0                4K            55
# 19               7599.0               19999.0                4K            62
# 20               7599.0               19999.0                4K            62
# 21               7599.0               19999.0                4K            62
# 22               4990.0               14900.0  HD READY/FULL HD            66
# 23              12299.0               21999.0           FULL HD            44
# 24               7599.0               19999.0                4K            62
# 25              14500.0               29999.0           FULL HD            51
# 26               7599.0               19999.0                4K            62
# 27               7599.0               19999.0                4K            62
#
#        Bank Offer     Limited Time Deal
# 0   No Bank Offer  No Limited Time Deal
# 1   No Bank Offer  No Limited Time Deal
# 2   No Bank Offer  No Limited Time Deal
# 3   No Bank Offer  No Limited Time Deal
# 4   No Bank Offer  No Limited Time Deal
# 5   No Bank Offer  No Limited Time Deal
# 6   No Bank Offer  No Limited Time Deal
# 7   No Bank Offer  No Limited Time Deal
# 8   No Bank Offer  No Limited Time Deal
# 9   No Bank Offer  No Limited Time Deal
# 10  No Bank Offer  No Limited Time Deal
# 11  No Bank Offer  No Limited Time Deal
# 12  No Bank Offer  No Limited Time Deal
# 13  No Bank Offer  No Limited Time Deal
# 14  No Bank Offer  No Limited Time Deal
# 15  No Bank Offer  No Limited Time Deal
# 16  No Bank Offer  No Limited Time Deal
# 17  No Bank Offer  No Limited Time Deal
# 18  No Bank Offer  No Limited Time Deal
# 19  No Bank Offer  No Limited Time Deal
# 20  No Bank Offer  No Limited Time Deal
# 21  No Bank Offer  No Limited Time Deal
# 22  No Bank Offer  No Limited Time Deal
# 23  No Bank Offer  No Limited Time Deal
# 24  No Bank Offer  No Limited Time Deal
# 25  No Bank Offer  No Limited Time Deal
# 26  No Bank Offer  No Limited Time Deal
# 27  No Bank Offer  No Limited Time Deal

# %%
df_tvs_nan["Product Type"].unique()
df_only_tvs_nan = df_tvs_nan[df_tvs_nan["Product Type"] == "Television"]
df_only_tvs_nan
# Out:
#     index                                Name of the Product Brand Name  \
# 0      68  PIXPAQ OG Pro (JAPAN), Extreme Bright 1400 ANS...     PIXPAQ
# 2     163  BPL 80 cm 32 (inch) HD Linux Smart TV with Dol...        BPL
# 3     164  BPL 80 cm 32 (inch) HD Linux Smart TV with Dol...        BPL
# 4     240    Haier 139.7 cm QLED Google Smart TV, Grey, 55Q6      Haier
# 5     241  Haier 165 cm 4K UHD Google Smart TV, Black, M65UG      Haier
# 6     242      Haier 109 cm QLED Google Smart TV, Grey, 43Q6      Haier
# 7     243      Haier 109 cm QLED Google Smart TV, Grey, 65Q6      Haier
# 8     292  TCL 75P635 75 inch (189 cm) 4K Ultra HD LED An...        TCL
# 9     293          Samsung 55 Neo QLED Smart LED TV, 55QN95C    Samsung
# 10    294          Samsung 50 Neo QLED Smart LED TV, 50QN90C    Samsung
# 11    295            Samsung 85 Neo QLED 8K LED TV, 85QN900C    Samsung
# 12    303         TCL 32 Full HD Smart Android TV, 32S5403AF        TCL
# 13    304                TCL 50 QLED Smart Google TV, 50C645        TCL
# 14    305          TCL 55 4K UHD Smart Google TV, 55P635 PRO        TCL
# 15    306          TCL 50 4K UHD Smart Google TV, 50P635 PRO        TCL
# 16    390  MI 32 HD Ready Smart LED TV, 4A Horizon, ELA45...         MI
# 17    409  TELESTONE 65" 4K UHD Smart LED TV | Smart TV |...  TELESTONE
# 18    410  TELESTONE 43" 4K UHD LED TV | Cloud Android Sm...  TELESTONE
# 19    411  TELESTONE 43" Full HD LED TV | Smart TV | Beze...  TELESTONE
# 20    412  TELESTONE 32" HD Ready LED TV | Smart Android ...  TELESTONE
# 21    413  TELESTONE 32" HD Ready Lite LED TV | Smart And...  TELESTONE
# 22    414  TELESTONE 32" GTV Smart LED TV | Smart TV | Go...  TELESTONE
# 32    538  Bush 40 inch (100 cm) FHD Smart LED TV, Black,...       Bush
# 33    539  Bush 43 inch (109 cm) FHD Smart LED TV, Black,...       Bush
# 34    549  Haier 139.7 cm 4K UHD Google Smart TV, Black, ...      Haier
# 35    557          Samsung 65 Neo QLED Smart LED TV, 65QN85C    Samsung
# 36    558          Samsung 85 Neo QLED Smart LED TV, 85QN90C    Samsung
# 37    563          TCL 65 4K UHD Smart Google TV, 65P635 PRO        TCL
# 38    568  Telestone 50-inch 4K UHD Frameless Smart LED T...  Telestone
# 39    569  TELESTONE 55" 4K UHD Smart LED TV | Smart TV |...  TELESTONE
# 40    570  Telestone 75-Inch UHD 4K Frameless Smart LED T...  Telestone
# 41    572  TELESTONE 43" GTV Smart LED TV | Smart TV | Go...  TELESTONE
# 46    613  ZuZu, move for more better. 2000 Lumen Portabl...      ZuZu,
# 47    646  Bush 32 inch (80 cm) HD Smart LED TV, Black, J...       Bush
# 48    647  Bush 24 inch (60 cm) HD Normal LED TV, Black, ...       Bush
# 49    677  Bush 50 inch (127 cm) 4K UHD Smart LED TV, Bla...       Bush
# 50    705          TCL 75 4K UHD Smart Google TV, 75P635 PRO        TCL
# 51    716          Samsung 65 Neo QLED Smart LED TV, 65QN95C    Samsung
#
#    Product Type  Selling Price (INR)  Original Price (INR)  Size (Inch)  \
# 0    Television              22999.0               26999.0          NaN
# 2    Television              11999.0               18500.0          NaN
# 3    Television              11999.0               18500.0          NaN
# 4    Television              55990.0               99990.0          NaN
# 5    Television              64990.0              110990.0          NaN
# 6    Television              38590.0               69990.0          NaN
# 7    Television              78989.0              135990.0          NaN
# 8    Television              60990.0              254990.0          NaN
# 9    Television             139988.0              244900.0          NaN
# 10   Television              84989.0              164900.0          NaN
# 11   Television             849990.0             1549900.0          NaN
# 12   Television              12989.0               20990.0          NaN
# 13   Television              32990.0              114990.0          NaN
# 14   Television              45989.0               79990.0          NaN
# 15   Television              30990.0               66990.0          NaN
# 16   Television              12989.0               19999.0          NaN
# 17   Television              59990.0               60990.0          NaN
# 18   Television              23990.0               24990.0          NaN
# 19   Television              18990.0               19990.0          NaN
# 20   Television              11990.0               12990.0          NaN
# 21   Television              10490.0               11490.0          NaN
# 22   Television              13990.0               14990.0          NaN
# 32   Television              11999.0               24999.0          NaN
# 33   Television              14999.0               28999.0          NaN
# 34   Television              43989.0               75990.0          NaN
# 35   Television             144990.0              249900.0          NaN
# 36   Television             499988.0              799900.0          NaN
# 37   Television              59990.0              126990.0          NaN
# 38   Television              34990.0               35990.0          NaN
# 39   Television              39990.0               40990.0          NaN
# 40   Television             109990.0              110990.0          NaN
# 41   Television              23990.0               24990.0          NaN
# 46   Television               9475.0               19999.0          NaN
# 47   Television               7999.0               17999.0          NaN
# 48   Television               6499.0               13999.0          NaN
# 49   Television              25999.0               40999.0          NaN
# 50   Television              79990.0              256990.0          NaN
# 51   Television             150000.0              329900.0          NaN
#
#     Size (cm)     Resolution  Discount (%)  \
# 0         NaN  Not Mentioned            14
# 2        80.0  Not Mentioned            35
# 3        80.0  Not Mentioned            35
# 4       139.7  Not Mentioned            44
# 5       165.0             4K            41
# 6       109.0  Not Mentioned            44
# 7       109.0  Not Mentioned            41
# 8       189.0             4K            76
# 9         NaN  Not Mentioned            42
# 10        NaN  Not Mentioned            48
# 11        NaN  Not Mentioned            45
# 12        NaN        FULL HD            38
# 13        NaN  Not Mentioned            71
# 14        NaN             4K            42
# 15        NaN             4K            53
# 16        NaN       HD READY            35
# 17        NaN             4K             1
# 18        NaN             4K             4
# 19        NaN        FULL HD             5
# 20        NaN       HD READY             7
# 21        NaN       HD READY             8
# 22        NaN       HD READY             6
# 32      100.0            FHD            52
# 33      109.0            FHD            48
# 34      139.7             4K            42
# 35        NaN  Not Mentioned            41
# 36        NaN  Not Mentioned            37
# 37        NaN             4K            52
# 38        NaN             4K             2
# 39        NaN             4K             2
# 40        NaN            UHD             0
# 41        NaN        FULL HD             4
# 46        NaN  Not Mentioned            52
# 47       80.0  Not Mentioned            55
# 48       60.0  Not Mentioned            53
# 49      127.0             4K            36
# 50        NaN             4K            68
# 51        NaN  Not Mentioned            54
#
#                                            Bank Offer     Limited Time Deal
# 0                                       No Bank Offer  No Limited Time Deal
# 2   Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 3   Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 4   Flat 12.5% Instant Discount On HDFC, ICICI, AX...  No Limited Time Deal
# 5   Flat 12.5% Instant Discount On HDFC, ICICI, AX...  No Limited Time Deal
# 6   Flat 12.5% Instant Discount On HDFC, ICICI, AX...  No Limited Time Deal
# 7   Flat 12.5% Instant Discount On HDFC, ICICI, AX...  No Limited Time Deal
# 8                                       No Bank Offer  No Limited Time Deal
# 9                                       No Bank Offer  No Limited Time Deal
# 10                                      No Bank Offer  No Limited Time Deal
# 11                                      No Bank Offer  No Limited Time Deal
# 12                                      No Bank Offer  No Limited Time Deal
# 13                                      No Bank Offer  No Limited Time Deal
# 14     Instant Discount On HDFC, ICICI, AXIS, SBI CC*  No Limited Time Deal
# 15                                      No Bank Offer  No Limited Time Deal
# 16                                      No Bank Offer  No Limited Time Deal
# 17                                      No Bank Offer  No Limited Time Deal
# 18                                      No Bank Offer  No Limited Time Deal
# 19                                      No Bank Offer  No Limited Time Deal
# 20                                      No Bank Offer  No Limited Time Deal
# 21                                      No Bank Offer  No Limited Time Deal
# 22                                      No Bank Offer  No Limited Time Deal
# 32  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 33  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 34  Flat 12.5% Instant Discount On HDFC, ICICI, AX...  No Limited Time Deal
# 35                                      No Bank Offer  No Limited Time Deal
# 36                                      No Bank Offer  No Limited Time Deal
# 37                                      No Bank Offer  No Limited Time Deal
# 38                                      No Bank Offer  No Limited Time Deal
# 39                                      No Bank Offer  No Limited Time Deal
# 40                                      No Bank Offer  No Limited Time Deal
# 41                                      No Bank Offer  No Limited Time Deal
# 46                                      No Bank Offer  No Limited Time Deal
# 47  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 48  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 49  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 50                                      No Bank Offer  No Limited Time Deal
# 51                                      No Bank Offer  No Limited Time Deal

# %%
df_only_tvs_nan.to_csv("jiomart_tvs_nan.csv", index=False)

# %%
df3 = pd.read_csv("jiomart_tvs_nan1.csv")
df2 = pd.concat([df_tvs, df3], ignore_index=True)
df2.drop(columns=['index'], inplace=True, errors='ignore')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589 entries, 0 to 588
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   589 non-null    object
#  1   Brand Name            589 non-null    object
#  2   Product Type          589 non-null    object
#  3   Selling Price (INR)   589 non-null    float64
#  4   Original Price (INR)  589 non-null    float64
#  5   Size (Inch)           537 non-null    float64
#  6   Size (cm)             550 non-null    float64
#  7   Resolution            589 non-null    object
#  8   Discount (%)          589 non-null    int64
#  9   Bank Offer            589 non-null    object
#  10  Limited Time Deal     589 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 50.7+ KB

# %%
df4 = pd.read_csv("jiomart_projectors_combined1.csv")
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   179 non-null    object
#  1   Brand Name            179 non-null    object
#  2   Product Type          179 non-null    object
#  3   Selling Price (INR)   179 non-null    float64
#  4   Original Price (INR)  179 non-null    float64
#  5   Resolution            179 non-null    object
#  6   Discount (%)          179 non-null    int64
#  7   Bank Offer            179 non-null    object
#  8   Limited Time Deal     179 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 12.7+ KB

# %%
df2["Selling Price (INR)"] = df2["Selling Price (INR)"].astype(int)
df2["Original Price (INR)"] = df2["Original Price (INR)"].astype(int)
df4["Selling Price (INR)"] = df4["Selling Price (INR)"].astype(int)
df4["Original Price (INR)"] = df4["Original Price (INR)"].astype(int)

# %%
df4
df2.to_csv("jiomart_tvs_combined.csv", index=False)
df4.to_csv("jiomart_projectors_combined.csv", index=False)

# %%
df5 = pd.concat([df2, df4], ignore_index=True)

# %%
df5
# Out:
#                                    Name of the Product Brand Name  \
# 0    Redmi 81.28 cm (32 inch) Smart Fire TV, Black,...      Redmi
# 1    Foxsky 80 cm (32 inch) HD Ready LED Smart TV, ...     Foxsky
# 2    Samsung wondertainment 80 cm (32 Inch) HD Read...    Samsung
# 3    Samsung 108 cm (43 Inch) 4K Ultra HD Smart TV ...    Samsung
# 4    LG 139.7 cm (55 inch) Ultra HD (4K) LED Smart ...         LG
# ..                                                 ...        ...
# 763  Torexo Sales T10 Full HD 1920*1080P Android Pr...     Torexo
# 764  YOTON Andriod 5G WiFi Projector Home 4K Suppor...      YOTON
# 765  ZuZu, move for more better. 3D Full HD LED Pro...      ZuZu,
# 766  IBS Mini ANDRIOD Projector for Home 4K Support...        IBS
# 767  METRONAUT Mini ANDRIOD Projector for Home 4K S...  METRONAUT
#
#     Product Type  Selling Price (INR)  Original Price (INR)  Size (Inch)  \
# 0     Television                10490                 24999         32.0
# 1     Television                 6999                 20999         32.0
# 2     Television                14490                 18990         32.0
# 3     Television                28990                 44900         43.0
# 4     Television                41990                 86990         55.0
# ..           ...                  ...                   ...          ...
# 763    Projector                12299                 21999          NaN
# 764    Projector                 7599                 19999          NaN
# 765    Projector                14500                 29999          NaN
# 766    Projector                 7599                 19999          NaN
# 767    Projector                 7599                 19999          NaN
#
#      Size (cm) Resolution  Discount (%)  \
# 0        81.28   HD READY            58
# 1        80.00   HD READY            66
# 2        80.00   HD READY            23
# 3       108.00         4K            35
# 4       139.70         4K            51
# ..         ...        ...           ...
# 763        NaN    FULL HD            44
# 764        NaN         4K            62
# 765        NaN    FULL HD            51
# 766        NaN         4K            62
# 767        NaN         4K            62
#
#                                             Bank Offer     Limited Time Deal
# 0    Flat 5% Instant Discount On HDFC, ICICI, AXIS,...     Limited Time Deal
# 1    Flat 5% Instant Discount On HDFC, ICICI, AXIS,...     Limited Time Deal
# 2                                  Limited Offer Price     Limited Time Deal
# 3    Flat 5% Instant Discount On HDFC, ICICI, AXIS,...     Limited Time Deal
# 4                                  Limited Offer Price     Limited Time Deal
# ..                                                 ...                   ...
# 763                                      No Bank Offer  No Limited Time Deal
# 764                                      No Bank Offer  No Limited Time Deal
# 765                                      No Bank Offer  No Limited Time Deal
# 766                                      No Bank Offer  No Limited Time Deal
# 767                                      No Bank Offer  No Limited Time Deal
#
# [768 rows x 11 columns]

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   768 non-null    object
#  1   Brand Name            768 non-null    object
#  2   Product Type          768 non-null    object
#  3   Selling Price (INR)   768 non-null    int64
#  4   Original Price (INR)  768 non-null    int64
#  5   Size (Inch)           537 non-null    float64
#  6   Size (cm)             550 non-null    float64
#  7   Resolution            768 non-null    object
#  8   Discount (%)          768 non-null    int64
#  9   Bank Offer            768 non-null    object
#  10  Limited Time Deal     768 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 66.1+ KB

# %%
df5.to_csv("jiomart_tvs_projectors_combined.csv", index=False)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   768 non-null    object
#  1   Brand Name            768 non-null    object
#  2   Product Type          768 non-null    object
#  3   Selling Price (INR)   768 non-null    int64
#  4   Original Price (INR)  768 non-null    int64
#  5   Size (Inch)           537 non-null    float64
#  6   Size (cm)             550 non-null    float64
#  7   Resolution            768 non-null    object
#  8   Discount (%)          768 non-null    int64
#  9   Bank Offer            768 non-null    object
#  10  Limited Time Deal     768 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 66.1+ KB

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   768 non-null    object
#  1   Brand Name            768 non-null    object
#  2   Product Type          768 non-null    object
#  3   Selling Price (INR)   768 non-null    int64
#  4   Original Price (INR)  768 non-null    int64
#  5   Size (Inch)           537 non-null    float64
#  6   Size (cm)             550 non-null    float64
#  7   Resolution            768 non-null    object
#  8   Discount (%)          768 non-null    int64
#  9   Bank Offer            768 non-null    object
#  10  Limited Time Deal     768 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 66.1+ KB

# %%
# Step 1: Get the original rows with NaNs in df_tvs (keep their index)
df_tvs_nan = df_tvs[df_tvs.isna().any(axis=1)].reset_index(drop=False)  # 'index' holds original row index

# Step 2: Read your manually cleaned file (with corrected sizes and product types)
df3 = pd.read_csv("jiomart_tvs_nan1.csv")

# Step 3: Drop the old versions of those rows from df_tvs using their original index
df_tvs_cleaned = df_tvs.drop(index=df_tvs_nan['index'])

# Step 4: Concatenate the cleaned rows back in
df_final = pd.concat([df_tvs_cleaned, df3], ignore_index=True)

# Step 5: Clean up any leftover 'index' column just in case
df_final.drop(columns=['index'], inplace=True, errors='ignore')

# Step 6: Optional – verify
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   537 non-null    object
#  1   Brand Name            537 non-null    object
#  2   Product Type          537 non-null    object
#  3   Selling Price (INR)   537 non-null    float64
#  4   Original Price (INR)  537 non-null    float64
#  5   Size (Inch)           537 non-null    float64
#  6   Size (cm)             537 non-null    float64
#  7   Resolution            537 non-null    object
#  8   Discount (%)          537 non-null    int64
#  9   Bank Offer            537 non-null    object
#  10  Limited Time Deal     537 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 46.3+ KB

# %%
df4
# Out:
#                                    Name of the Product Brand Name  \
# 0    Hespa Mini Projector LED Home Theater with Rem...      Hespa
# 1    Hespa Mini Projector LED Home Theater with Rem...      Hespa
# 2    Hespa Portable Mini Projector LED Home Theater...      Hespa
# 3    Hespa YG-300 HD Smart Mini Movie Projector LED...      Hespa
# 4    Hespa Full HD Mini Projector LED Home Theater ...      Hespa
# ..                                                 ...        ...
# 174  Torexo Sales T10 Full HD 1920*1080P Android Pr...     Torexo
# 175  YOTON Andriod 5G WiFi Projector Home 4K Suppor...      YOTON
# 176  ZuZu, move for more better. 3D Full HD LED Pro...      ZuZu,
# 177  IBS Mini ANDRIOD Projector for Home 4K Support...        IBS
# 178  METRONAUT Mini ANDRIOD Projector for Home 4K S...  METRONAUT
#
#     Product Type  Selling Price (INR)  Original Price (INR)        Resolution  \
# 0      Projector                 1299                  2999  HD READY/FULL HD
# 1      Projector                 1299                  2999  HD READY/FULL HD
# 2      Projector                 1299                  2999  HD READY/FULL HD
# 3      Projector                 1299                  2999  HD READY/FULL HD
# 4      Projector                 1399                  2999           FULL HD
# ..           ...                  ...                   ...               ...
# 174    Projector                12299                 21999           FULL HD
# 175    Projector                 7599                 19999                4K
# 176    Projector                14500                 29999           FULL HD
# 177    Projector                 7599                 19999                4K
# 178    Projector                 7599                 19999                4K
#
#      Discount (%)     Bank Offer     Limited Time Deal
# 0              56  No Bank Offer  No Limited Time Deal
# 1              56  No Bank Offer  No Limited Time Deal
# 2              56  No Bank Offer  No Limited Time Deal
# 3              56  No Bank Offer  No Limited Time Deal
# 4              53  No Bank Offer  No Limited Time Deal
# ..            ...            ...                   ...
# 174            44  No Bank Offer  No Limited Time Deal
# 175            62  No Bank Offer  No Limited Time Deal
# 176            51  No Bank Offer  No Limited Time Deal
# 177            62  No Bank Offer  No Limited Time Deal
# 178            62  No Bank Offer  No Limited Time Deal
#
# [179 rows x 9 columns]

# %%
df_final
# Out:
#                                    Name of the Product Brand Name  \
# 0    Redmi 81.28 cm (32 inch) Smart Fire TV, Black,...      Redmi
# 1    Foxsky 80 cm (32 inch) HD Ready LED Smart TV, ...     Foxsky
# 2    Samsung wondertainment 80 cm (32 Inch) HD Read...    Samsung
# 3    Samsung 108 cm (43 Inch) 4K Ultra HD Smart TV ...    Samsung
# 4    LG 139.7 cm (55 inch) Ultra HD (4K) LED Smart ...         LG
# ..                                                 ...        ...
# 532  Bush 32 inch (80 cm) HD Smart LED TV, Black, J...       Bush
# 533  Bush 24 inch (60 cm) HD Normal LED TV, Black, ...       Bush
# 534  Bush 50 inch (127 cm) 4K UHD Smart LED TV, Bla...       Bush
# 535          TCL 75 4K UHD Smart Google TV, 75P635 PRO        TCL
# 536          Samsung 65 Neo QLED Smart LED TV, 65QN95C    Samsung
#
#     Product Type  Selling Price (INR)  Original Price (INR)  Size (Inch)  \
# 0     Television              10490.0               24999.0         32.0
# 1     Television               6999.0               20999.0         32.0
# 2     Television              14490.0               18990.0         32.0
# 3     Television              28990.0               44900.0         43.0
# 4     Television              41990.0               86990.0         55.0
# ..           ...                  ...                   ...          ...
# 532   Television               7999.0               17999.0         32.0
# 533   Television               6499.0               13999.0         24.0
# 534   Television              25999.0               40999.0         50.0
# 535   Television              79990.0              256990.0         75.0
# 536   Television             150000.0              329900.0         65.0
#
#      Size (cm) Resolution  Discount (%)  \
# 0        81.28   HD READY            58
# 1        80.00   HD READY            66
# 2        80.00   HD READY            23
# 3       108.00         4K            35
# 4       139.70         4K            51
# ..         ...        ...           ...
# 532      80.00   HD READY            55
# 533      60.00   HD READY            53
# 534     127.00         4K            36
# 535     189.00         4K            68
# 536     165.00         4K            54
#
#                                             Bank Offer     Limited Time Deal
# 0    Flat 5% Instant Discount On HDFC, ICICI, AXIS,...     Limited Time Deal
# 1    Flat 5% Instant Discount On HDFC, ICICI, AXIS,...     Limited Time Deal
# 2                                  Limited Offer Price     Limited Time Deal
# 3    Flat 5% Instant Discount On HDFC, ICICI, AXIS,...     Limited Time Deal
# 4                                  Limited Offer Price     Limited Time Deal
# ..                                                 ...                   ...
# 532  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 533  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 534  Flat 5% Instant Discount On HDFC, ICICI, AXIS,...  No Limited Time Deal
# 535                                      No Bank Offer  No Limited Time Deal
# 536                                      No Bank Offer  No Limited Time Deal
#
# [537 rows x 11 columns]

# %%
df_cleaned_total_tvs_projectors = pd.concat([df_final, df4], ignore_index=True)
df_cleaned_total_tvs_projectors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name of the Product   716 non-null    object
#  1   Brand Name            716 non-null    object
#  2   Product Type          716 non-null    object
#  3   Selling Price (INR)   716 non-null    float64
#  4   Original Price (INR)  716 non-null    float64
#  5   Size (Inch)           537 non-null    float64
#  6   Size (cm)             537 non-null    float64
#  7   Resolution            716 non-null    object
#  8   Discount (%)          716 non-null    int64
#  9   Bank Offer            716 non-null    object
#  10  Limited Time Deal     716 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 61.7+ KB

# %%
df_cleaned_total_tvs_projectors.to_csv("jiomart_tvs_projectors_combined_final.csv", index=False)
